# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible): Traceback (most recent call last):
#   File "/home/pengejeen/.local/bin/huggingface-cli", line 8, in <module>
#     sys.exit(main())
#   File "/home/pengejeen/.local/lib/python3.10/site-packages/huggingface_hub/commands/huggingface_cli.py", line 51, in main
#     service.run()
#   File "/home/pengejeen/.local/lib/python3.10/site-packages/huggingface_hub/commands/user.py", line 98, in run
#     login(token=self.args.token, add_to_git_credential=self.args.add_to_git_credential)
#   File "/home/pengejeen/.local/lib/python3.10/site-packages/huggingface_hub/_login.py", line 115, in login
#     interpreter_login(new_session=new_session, write_permission=write_permission)
#   File "/home/pengejeen/.local/lib/python3.10/site-packages/huggingface_hub/_login.py", line 191, in interpreter_login
#     token = getpass("Enter your token (input will not be visible): ")
#   File "/usr/lib/python3.10/getpass.py", line 77, in unix_getpass
#     passwd = _raw_input(prompt, stream, input=input)
#   File "/usr/lib/python3.10/getpass.py", line 146, in _raw_input
#     line = input.readline()
#   File "/usr/lib/python3.10/codecs.py", line 319, in decode
#     def decode(self, input, final=False):
# KeyboardInterrupt

# %%
from itertools import islice
from datasets import load_dataset
import soundfile as sf
import os

# 스트리밍 옵션으로 데이터셋 로드
dataset = load_dataset('simon3000/genshin-voice', split='train', streaming=True)

# 한국어 Paimon 음성과 전사(transcription)가 있는 데이터를 필터링하는 함수 정의
def filter_korean_paimon(example):
    return example['language'] == 'Korean' and example['speaker'] == 'Paimon' and example['transcription'] != ''

# 폴더 생성
paimon_folder = 'paimon_voices'
os.makedirs(paimon_folder, exist_ok=True)
# 데이터셋의 일부분만 처리
batch_size = 100  # 한 번에 처리할 데이터 개수
i = 1

# 데이터 처리 루프
start_index = 0  # 시작 인덱스 설정
while True:
    # 데이터셋에서 시작 인덱스부터 배치를 가져옴
    batch = list(islice(dataset, start_index, start_index + batch_size))
    if not batch:
        break

    for example in batch:
        # 필터링 조건 확인
        if filter_korean_paimon(example):
            audio_path = os.path.join(paimon_folder, f'{i}_audio.wav')  # 오디오 파일 저장 경로
            transcription_path = os.path.join(paimon_folder, f'{i}_transcription.txt')  # 전사 파일 저장 경로

            # 오디오 데이터 저장
            audio = example['audio']
            sf.write(audio_path, audio['array'], audio['sampling_rate'])

            # 전사 데이터 저장
            with open(transcription_path, 'w') as transcription_file:
                transcription_file.write(example['transcription'])

            print(f'{i} done')
            i += 1

    # 다음 반복을 위해 시작 인덱스 업데이트
    start_index += batch_size
# Out:
# Resolving data files:   0%|          | 0/47 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/47 [00:00<?, ?it/s]
# 1 done
# 2 done
# 3 done
# 4 done
# 5 done
# 6 done
# 7 done
# 8 done
# 9 done
# 10 done
# 11 done
# 12 done
# 13 done
# 14 done
# 15 done
# 16 done
# 17 done
# 18 done
# 19 done
# 20 done
# 21 done
# 22 done
# 23 done
# 24 done
# 25 done
# 26 done
# 27 done
# 28 done
# 29 done
# 30 done
# 31 done
# 32 done
# 33 done
# 34 done
# 35 done
# 36 done
# 37 done
# 38 done
# 39 done
# 40 done
# 41 done
# 42 done
# 43 done
# 44 done
# 45 done
# 46 done
# 47 done
# 48 done
# 49 done
# 50 done
# 51 done
# 52 done
# 53 done
# 54 done
# 55 done
# 56 done
# 57 done
# 58 done
# 59 done
# 60 done
# 61 done
# 62 done
# 63 done
# 64 done
# 65 done
# 66 done
# 67 done
# 68 done
# 69 done
# 70 done
# 71 done
# 72 done
# 73 done
# 74 done
# 75 done
# 76 done
# 77 done
# 78 done
# 79 done
# 80 done
# 81 done
# 82 done
# 83 done
# 84 done
# 85 done
# 86 done
# 87 done
# 88 done
# 89 done
# 90 done
# 91 done
# 92 done
# 93 done
# 94 done
# 95 done
# 96 done
# 97 done
# 98 done
# 99 done
# 100 done
# 101 done
# 102 done
# 103 done
# 104 done
# 105 done
# 106 done
# 107 done
# 108 done
# 109 done
# 110 done
# 111 done
# 112 done
# 113 done
# 114 done
# 115 done
# 116 done
# 117 done
# 118 done
# 119 done
# 120 done
# 121 done
# 122 done
# 123 done
# 124 done
# 125 done
# 126 done
# 127 done
# 128 done
# 129 done
# 130 done
# 131 done
# 132 done
# 133 done
# 134 done
# 135 done
# 136 done
# 137 done
# 138 done
# 139 done
# 140 done
# 141 done
# 142 done
# 143 done
# 144 done
# 145 done
# 146 done
# 147 done
# 148 done
# 149 done
# 150 done
# 151 done
# 152 done
# 153 done
# 154 done
# 155 done
# 156 done
# 157 done
# 158 done
# 159 done
# 160 done
# 161 done
# 162 done
# 163 done
# 164 done
# 165 done
# 166 done
# 167 done
# 168 done
# 169 done
# 170 done
# 171 done
# 172 done
# 173 done
# 174 done
# 175 done
# 176 done
# 177 done
# 178 done
# 179 done
# 180 done
# 181 done
# 182 done
# 183 done
# 184 done
# 185 done
# 186 done
# 187 done
# 188 done
# 189 done
# 190 done
# 191 done
# 192 done
# 193 done
# 194 done
# 195 done
# 196 done
# 197 done
# 198 done
# 199 done
# 200 done
# 201 done
# 202 done
# 203 done
# 204 done
# 205 done
# 206 done
# 207 done
# 208 done
# 209 done
# 210 done
# 211 done
# 212 done
# 213 done
# 214 done
# 215 done
# 216 done
# 217 done
# 218 done
# 219 done
# 220 done
# 221 done
# 222 done
# 223 done
# 224 done
# 225 done
# 226 done
# 227 done
# 228 done
# 229 done
# 230 done
# 231 done
# 232 done
# 233 done
# 234 done
# 235 done
# 236 done
# 237 done
# 238 done
# 239 done
# 240 done
# 241 done
# 242 done
# 243 done
# 244 done
# 245 done
# 246 done
# 247 done
# 248 done
# 249 done
# 250 done
# 251 done
# 252 done
# 253 done
# 254 done
# 255 done
# 256 done
# 257 done
# 258 done
# 259 done
# 260 done
# 261 done
# 262 done
# 263 done
# 264 done
# 265 done
# 266 done
# 267 done
# 268 done
# 269 done
# 270 done
# 271 done
# 272 done
# 273 done
# 274 done
# 275 done
# 276 done
# 277 done
# 278 done
# 279 done
# 280 done
# 281 done
# 282 done
# 283 done
# 284 done
# 285 done
# 286 done
# 287 done
# 288 done
# 289 done
# 290 done
# 291 done
# 292 done
# 293 done
# 294 done
# 295 done
# 296 done
# 297 done
# 298 done
# 299 done
# 300 done
# 301 done
# 302 done
# 303 done
# 304 done
# 305 done
# 306 done
# 307 done
# 308 done
# 309 done
# 310 done
# 311 done
# 312 done
# 313 done
# 314 done
# 315 done
# 316 done
# 317 done
# 318 done
# 319 done
# 320 done
# 321 done
# 322 done
# 323 done
# 324 done
# 325 done
# 326 done
# 327 done
# 328 done
# 329 done
# 330 done
# 331 done
# 332 done
# 333 done
# 334 done
# 335 done
# 336 done
# 337 done
# 338 done
# 339 done
# 340 done
# 341 done
# 342 done
# 343 done
# 344 done
# 345 done
# 346 done
# 347 done
# 348 done
# 349 done
# 350 done
# 351 done
# 352 done
# 353 done
# 354 done
# 355 done
# 356 done
# 357 done
# 358 done
# 359 done
# 360 done
# 361 done
# 362 done
# 363 done
# 364 done
# 365 done
# 366 done
# 367 done
# 368 done
# 369 done
# 370 done
# 371 done
# 372 done
# 373 done
# 374 done
# 375 done
# 376 done
# 377 done
# 378 done
# 379 done
# 380 done
# 381 done
# 382 done
# 383 done
# 384 done
# 385 done
# 386 done

# %%
import os

i = 1

result_txt = ""
paimon_folder = 'datasets/wavs'

while True:
    tmp_txt = ""

    audio_path = f'{i}_audio'  # 오디오 파일 저장 경로
    transcription_path = os.path.join(paimon_folder, f'{i}_transcription.txt')  # 전사 파일 저장 경로
    try:
        with open(transcription_path, 'r') as transcription_file:
            transcription = transcription_file.read()

        tmp_txt = f"{audio_path},{transcription}\n"
        result_txt += tmp_txt
        i += 1
    except:
        print("done")
        break;
# Out:
# done

# %%
with open("./datasets/metadata.csv", 'w') as file:
    file.write(result_txt)

# %% [raw]
# 여기서부터는 finetuning
# TTS finetuning
# https://docs.coqui.ai/en/latest/finetuning.html
#
# XTTS
# https://www.gpters.org/c/ai-developers/2c022a
#
# /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2
#
# tokenizer.encode
# https://github.com/coqui-ai/TTS/issues/3356

# %%
# !CUDA_VISIBLE_DEVICES="0" python3 /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/train_gpt_xtts.py
#    --restore_path  /home/pengejeen/.local/share/tts/tts_models--multilingual--multi-dataset--xtts_v2/model.pth \
# Out:
# >> DVAE weights restored from: /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/XTTS_v2.0_original_model_files/dvae.pth
#  | > Found 386 files in /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/datasets
#  > Training Environment:
#  | > Backend: Torch
#  | > Mixed precision: False
#  | > Precision: float32
#  | > Current device: 0
#  | > Num. of GPUs: 1
#  | > Num. of CPUs: 12
#  | > Num. of Torch Threads: 1
#  | > Torch seed: 1
#  | > Torch CUDNN: True
#  | > Torch CUDNN deterministic: False
#  | > Torch CUDNN benchmark: False
#  | > Torch TF32 MatMul: False
#  > Start Tensorboard: tensorboard --logdir=/home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_09+00PM-64158d0
#
#  > Model has 518442047 parameters
#
#  > EPOCH: 0/6
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_09+00PM-64158d0
#  > Filtering invalid eval samples!!
#  > Total eval samples after filtering: 3
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.6920089721679688 (+0)
#      | > avg_loss_text_ce: 0.0338304303586483 (+0)
#      | > avg_loss_mel_ce: 3.4577364921569824 (+0)
#      | > avg_loss: 3.4915668964385986 (+0)
#
#
#  > EPOCH: 1/6
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_09+00PM-64158d0
#  > Sampling by language: dict_keys(['ko'])
#
#  > TRAINING (2024-05-24 21:00:18)
#
#    --> TIME: 2024-05-24 21:00:28 -- STEP: 0/128 -- GLOBAL_STEP: 0
#      | > loss_text_ce: 0.03583338484168053  (0.03583338484168053)
#      | > loss_mel_ce: 3.916569471359253  (3.916569471359253)
#      | > loss: 0.04705241695046425  (0.04705241695046425)
#      | > current_lr: 5e-06
#      | > step_time: 9.4056  (9.405604362487793)
#      | > loader_time: 0.5275  (0.5274765491485596)
#
#
#    --> TIME: 2024-05-24 21:02:59 -- STEP: 50/128 -- GLOBAL_STEP: 50
#      | > loss_text_ce: 0.035603947937488556  (0.03536011051386594)
#      | > loss_mel_ce: 3.8167121410369873  (3.652122778892517)
#      | > loss: 0.045860908925533295  (0.043898606449365614)
#      | > current_lr: 5e-06
#      | > step_time: 1.4863  (2.6285092973709117)
#      | > loader_time: 0.0172  (0.023076696395874022)
#
#
#    --> TIME: 2024-05-24 21:05:32 -- STEP: 100/128 -- GLOBAL_STEP: 100
#      | > loss_text_ce: 0.03463628143072128  (0.03533158527687193)
#      | > loss_mel_ce: 3.775564670562744  (3.6299622797966005)
#      | > loss: 0.0453595370054245  (0.043634451664984225)
#      | > current_lr: 5e-06
#      | > step_time: 2.5603  (2.5552255463600173)
#      | > loader_time: 0.0218  (0.018761630058288566)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.0473175048828125 (-0.6446914672851562)
#      | > avg_loss_text_ce: 0.033782634884119034 (-4.779547452926636e-05)
#      | > avg_loss_mel_ce: 3.235058069229126 (-0.22267842292785645)
#      | > avg_loss: 3.268840789794922 (-0.22272610664367676)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_09+00PM-64158d0/best_model_128.pth
#
#  > EPOCH: 2/6
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_09+00PM-64158d0
#
#  > TRAINING (2024-05-24 21:07:58)
#
#    --> TIME: 2024-05-24 21:10:02 -- STEP: 22/128 -- GLOBAL_STEP: 150
#      | > loss_text_ce: 0.03855572268366814  (0.035271215421909634)
#      | > loss_mel_ce: 4.615252494812012  (3.530510978265242)
#      | > loss: 0.0554024800658226  (0.04244978912174702)
#      | > current_lr: 5e-06
#      | > step_time: 4.3476  (3.651412996378812)
#      | > loader_time: 0.0058  (0.01747245138341731)
#
#
#    --> TIME: 2024-05-24 21:15:33 -- STEP: 72/128 -- GLOBAL_STEP: 200
#      | > loss_text_ce: 0.038420550525188446  (0.035144951091044464)
#      | > loss_mel_ce: 3.6619932651519775  (3.4844804637961917)
#      | > loss: 0.044052544981241226  (0.04190030347348915)
#      | > current_lr: 5e-06
#      | > step_time: 3.679  (4.114876081546147)
#      | > loader_time: 0.02  (0.013472480906380547)
#
#
#    --> TIME: 2024-05-24 21:21:22 -- STEP: 122/128 -- GLOBAL_STEP: 250
#      | > loss_text_ce: 0.03484344109892845  (0.03467896145569984)
#      | > loss_mel_ce: 3.0257821083068848  (3.4506354156087657)
#      | > loss: 0.036436017602682114  (0.041491838660640795)
#      | > current_lr: 5e-06
#      | > step_time: 5.1611  (4.308606171217121)
#      | > loader_time: 0.0207  (0.012077882641651591)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.029577255249023438 (-0.017740249633789062)
#      | > avg_loss_text_ce: 0.03372599184513092 (-5.66430389881134e-05)
#      | > avg_loss_mel_ce: 3.099311113357544 (-0.13574695587158203)
#      | > avg_loss: 3.1330370903015137 (-0.1358036994934082)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_09+00PM-64158d0/best_model_256.pth
#
#  > EPOCH: 3/6
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_09+00PM-64158d0
#
#  > TRAINING (2024-05-24 21:22:13)
#
#    --> TIME: 2024-05-24 21:26:05 -- STEP: 44/128 -- GLOBAL_STEP: 300
#      | > loss_text_ce: 0.031133608892560005  (0.03572185832837766)
#      | > loss_mel_ce: 3.4880547523498535  (3.385817874561656)
#      | > loss: 0.041895098984241486  (0.04073261664333669)
#      | > current_lr: 5e-06
#      | > step_time: 4.0571  (3.732450983741067)
#      | > loader_time: 0.0064  (0.013519704341888428)
#
#
#    --> TIME: 2024-05-24 21:30:34 -- STEP: 94/128 -- GLOBAL_STEP: 350
#      | > loss_text_ce: 0.033154964447021484  (0.03496794329282452)
#      | > loss_mel_ce: 3.0158193111419678  (3.3245701992765384)
#      | > loss: 0.03629731386899948  (0.039994502598617906)
#      | > current_lr: 5e-06
#      | > step_time: 4.2992  (3.7081369186969515)
#      | > loader_time: 0.0063  (0.012238593811684467)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.03710627555847168 (+0.007529020309448242)
#      | > avg_loss_text_ce: 0.03363450616598129 (-9.148567914962769e-05)
#      | > avg_loss_mel_ce: 3.0401298999786377 (-0.05918121337890625)
#      | > avg_loss: 3.0737643241882324 (-0.05927276611328125)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_09+00PM-64158d0/best_model_384.pth
#
#  > EPOCH: 4/6
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_09+00PM-64158d0
#
#  > TRAINING (2024-05-24 21:33:57)
#
#    --> TIME: 2024-05-24 21:35:06 -- STEP: 16/128 -- GLOBAL_STEP: 400
#      | > loss_text_ce: 0.028988732025027275  (0.034941407036967576)
#      | > loss_mel_ce: 3.240669012069702  (3.237126499414444)
#      | > loss: 0.03892450034618378  (0.03895318997092545)
#      | > current_lr: 5e-06
#      | > step_time: 2.0934  (2.9204434603452682)
#      | > loader_time: 0.0059  (0.006172284483909607)
#
#
#    --> TIME: 2024-05-24 21:39:21 -- STEP: 66/128 -- GLOBAL_STEP: 450
#      | > loss_text_ce: 0.031078176572918892  (0.033840940079905756)
#      | > loss_mel_ce: 3.1258347034454346  (3.2392762754902695)
#      | > loss: 0.03758229687809944  (0.038965681850007094)
#      | > current_lr: 5e-06
#      | > step_time: 3.853  (3.4019352342143203)
#      | > loader_time: 0.0055  (0.006473176407091545)
#
#
#    --> TIME: 2024-05-24 21:43:19 -- STEP: 116/128 -- GLOBAL_STEP: 500
#      | > loss_text_ce: 0.03188330680131912  (0.03383550007731237)
#      | > loss_mel_ce: 3.2764408588409424  (3.224156702386922)
#      | > loss: 0.039384812116622925  (0.03878562226249226)
#      | > current_lr: 5e-06
#      | > step_time: 3.812  (3.3436552573894636)
#      | > loader_time: 0.0055  (0.0064752512964709056)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.03774762153625488 (+0.0006413459777832031)
#      | > avg_loss_text_ce: 0.033539507538080215 (-9.499862790107727e-05)
#      | > avg_loss_mel_ce: 3.0030384063720703 (-0.03709149360656738)
#      | > avg_loss: 3.0365779399871826 (-0.037186384201049805)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_09+00PM-64158d0/best_model_512.pth
#
#  > EPOCH: 5/6
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_09+00PM-64158d0
#
#  > TRAINING (2024-05-24 21:44:40)
#
#    --> TIME: 2024-05-24 21:47:54 -- STEP: 38/128 -- GLOBAL_STEP: 550
#      | > loss_text_ce: 0.033393580466508865  (0.0341482672252153)
#      | > loss_mel_ce: 2.974248170852661  (3.154043348211991)
#      | > loss: 0.03580525889992714  (0.037954662877478104)
#      | > current_lr: 5e-06
#      | > step_time: 6.5706  (3.1435306260460303)
#      | > loader_time: 0.0058  (0.008137765683625875)
#
#
#    --> TIME: 2024-05-24 21:52:00 -- STEP: 88/128 -- GLOBAL_STEP: 600
#      | > loss_text_ce: 0.0297755878418684  (0.03356188199144194)
#      | > loss_mel_ce: 2.9644811153411865  (3.1874151744625787)
#      | > loss: 0.03564591333270073  (0.038344965655017986)
#      | > current_lr: 5e-06
#      | > step_time: 2.3181  (3.097716149958697)
#      | > loader_time: 0.0054  (0.00760300863872875)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02352309226989746 (-0.014224529266357422)
#      | > avg_loss_text_ce: 0.03342650085687637 (-0.00011300668120384216)
#      | > avg_loss_mel_ce: 2.9720535278320312 (-0.030984878540039062)
#      | > avg_loss: 3.0054800510406494 (-0.031097888946533203)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_09+00PM-64158d0/best_model_640.pth

# %%
import os
import torch
import torchaudio
from TTS.tts.configs.xtts_config import XttsConfig
from TTS.tts.models.xtts import Xtts

#if you learning new model, please update PATH
PATH = "/home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_09+00PM-64158d0"

TOKENIZER_PATH = "/home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/XTTS_v2.0_original_model_files/vocab.json"

print("Loading model...")
config = XttsConfig()
config.load_json(f"{PATH}/config.json")

model = Xtts.init_from_config(config)
model.load_checkpoint(
    config,
    checkpoint_dir = f"{PATH}",
    vocab_path = TOKENIZER_PATH,
    use_deepspeed=False  
)
model.cuda()
# Out:
# Loading model...
# Xtts(
#   (gpt): GPT(
#     (conditioning_encoder): ConditioningEncoder(
#       (init): Conv1d(80, 1024, kernel_size=(1,), stride=(1,))
#       (attn): Sequential(
#         (0): AttentionBlock(
#           (norm): GroupNorm32(32, 1024, eps=1e-05, affine=True)
#           (qkv): Conv1d(1024, 3072, kernel_size=(1,), stride=(1,))
#           (attention): QKVAttention()
#           (x_proj): Identity()
#           (proj_out): Conv1d(1024, 1024, kernel_size=(1,), stride=(1,))
#         )
#         (1): AttentionBlock(
#           (norm): GroupNorm32(32, 1024, eps=1e-05, affine=True)
#           (qkv): Conv1d(1024, 3072, kernel_size=(1,), stride=(1,))
#           (attention): QKVAttention()
#           (x_proj): Identity()
#           (proj_out): Conv1d(1024, 1024, kernel_size=(1,), stride=(1,))
#         )
#         (2): AttentionBlock(
#           (norm): GroupNorm32(32, 1024, eps=1e-05, affine=True)
#           (qkv): Conv1d(1024, 3072, kernel_size=(1,), stride=(1,))
#           (attention): QKVAttention()
#           (x_proj): Identity()
#           (proj_out): Conv1d(1024, 1024, kernel_size=(1,), stride=(1,))
#         )
#         (3): AttentionBlock(
#           (norm): GroupNorm32(32, 1024, eps=1e-05, affine=True)
#           (qkv): Conv1d(1024, 3072, kernel_size=(1,), stride=(1,))
#           (attention): QKVAttention()
#           (x_proj): Identity()
#           (proj_out): Conv1d(1024, 1024, kernel_size=(1,), stride=(1,))
#         )
#         (4): AttentionBlock(
#           (norm): GroupNorm32(32, 1024, eps=1e-05, affine=True)
#           (qkv): Conv1d(1024, 3072, kernel_size=(1,), stride=(1,))
#           (attention): QKVAttention()
#           (x_proj): Identity()
#           (proj_out): Conv1d(1024, 1024, kernel_size=(1,), stride=(1,))
#         )
#         (5): AttentionBlock(
#           (norm): GroupNorm32(32, 1024, eps=1e-05, affine=True)
#           (qkv): Conv1d(1024, 3072, kernel_size=(1,), stride=(1,))
#           (attention): QKVAttention()
#           (x_proj): Identity()
#           (proj_out): Conv1d(1024, 1024, kernel_size=(1,), stride=(1,))
#         )
#       )
#     )
#     (conditioning_dropout): Dropout1d(p=0.1, inplace=False)
#     (text_embedding): Embedding(6681, 1024)
#     (mel_embedding): Embedding(1026, 1024)
#     (gpt): GPT2Model(
#       (drop): Dropout(p=0.1, inplace=False)
#       (h): ModuleList(
#         (0-29): 30 x GPT2Block(
#           (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.1, inplace=False)
#             (resid_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (ln_f): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (wte): Embedding(1026, 1024)
#     )
#     (mel_pos_embedding): LearnedPositionEmbeddings(
#       (emb): Embedding(608, 1024)
#     )
#     (text_pos_embedding): LearnedPositionEmbeddings(
#       (emb): Embedding(404, 1024)
#     )
#     (final_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (text_head): Linear(in_features=1024, out_features=6681, bias=True)
#     (mel_head): Linear(in_features=1024, out_features=1026, bias=True)
#     (conditioning_perceiver): PerceiverResampler(
#       (proj_context): Identity()
#       (layers): ModuleList(
#         (0-1): 2 x ModuleList(
#           (0): Attention(
#             (attend): Attend(
#               (attn_dropout): Dropout(p=0.0, inplace=False)
#             )
#             (to_q): Linear(in_features=1024, out_features=512, bias=False)
#             (to_kv): Linear(in_features=1024, out_features=1024, bias=False)
#             (to_out): Linear(in_features=512, out_features=1024, bias=False)
#           )
#           (1): Sequential(
#             (0): Linear(in_features=1024, out_features=5460, bias=True)
#             (1): GEGLU()
#             (2): Linear(in_features=2730, out_features=1024, bias=True)
#           )
#         )
#       )
#       (norm): RMSNorm()
#     )
#     (gpt_inference): GPT2InferenceModel(
#       (transformer): GPT2Model(
#         (drop): Dropout(p=0.1, inplace=False)
#         (h): ModuleList(
#           (0-29): 30 x GPT2Block(
#             (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (attn): GPT2Attention(
#               (c_attn): Conv1D()
#               (c_proj): Conv1D()
#               (attn_dropout): Dropout(p=0.1, inplace=False)
#               (resid_dropout): Dropout(p=0.1, inplace=False)
#             )
#             (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (mlp): GPT2MLP(
#               (c_fc): Conv1D()
#               (c_proj): Conv1D()
#               (act): NewGELUActivation()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (ln_f): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (wte): Embedding(1026, 1024)
#       )
#       (pos_embedding): LearnedPositionEmbeddings(
#         (emb): Embedding(608, 1024)
#       )
#       (embeddings): Embedding(1026, 1024)
#       (final_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (lm_head): Sequential(
#         (0): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (1): Linear(in_features=1024, out_features=1026, bias=True)
#       )
#     )
#   )
#   (hifigan_decoder): HifiDecoder(
#     (waveform_decoder): HifiganGenerator(
#       (conv_pre): Conv1d(1024, 512, kernel_size=(7,), stride=(1,), padding=(3,))
#       (ups): ModuleList(
#         (0): ParametrizedConvTranspose1d(
#           512, 256, kernel_size=(16,), stride=(8,), padding=(4,)
#           (parametrizations): ModuleDict(
#             (weight): ParametrizationList(
#               (0): _WeightNorm()
#             )
#           )
#         )
#         (1): ParametrizedConvTranspose1d(
#           256, 128, kernel_size=(16,), stride=(8,), padding=(4,)
#           (parametrizations): ModuleDict(
#             (weight): ParametrizationList(
#               (0): _WeightNorm()
#             )
#           )
#         )
#         (2): ParametrizedConvTranspose1d(
#           128, 64, kernel_size=(4,), stride=(2,), padding=(1,)
#           (parametrizations): ModuleDict(
#             (weight): ParametrizationList(
#               (0): _WeightNorm()
#             )
#           )
#         )
#         (3): ParametrizedConvTranspose1d(
#           64, 32, kernel_size=(4,), stride=(2,), padding=(1,)
#           (parametrizations): ModuleDict(
#             (weight): ParametrizationList(
#               (0): _WeightNorm()
#             )
#           )
#         )
#       )
#       (resblocks): ModuleList(
#         (0): ResBlock1(
#           (convs1): ModuleList(
#             (0): ParametrizedConv1d(
#               256, 256, kernel_size=(3,), stride=(1,), padding=(1,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#             (1): ParametrizedConv1d(
#               256, 256, kernel_size=(3,), stride=(1,), padding=(3,), dilation=(3,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#             (2): ParametrizedConv1d(
#               256, 256, kernel_size=(3,), stride=(1,), padding=(5,), dilation=(5,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#           (convs2): ModuleList(
#             (0-2): 3 x ParametrizedConv1d(
#               256, 256, kernel_size=(3,), stride=(1,), padding=(1,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#         )
#         (1): ResBlock1(
#           (convs1): ModuleList(
#             (0): ParametrizedConv1d(
#               256, 256, kernel_size=(7,), stride=(1,), padding=(3,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#             (1): ParametrizedConv1d(
#               256, 256, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#             (2): ParametrizedConv1d(
#               256, 256, kernel_size=(7,), stride=(1,), padding=(15,), dilation=(5,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#           (convs2): ModuleList(
#             (0-2): 3 x ParametrizedConv1d(
#               256, 256, kernel_size=(7,), stride=(1,), padding=(3,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#         )
#         (2): ResBlock1(
#           (convs1): ModuleList(
#             (0): ParametrizedConv1d(
#               256, 256, kernel_size=(11,), stride=(1,), padding=(5,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#             (1): ParametrizedConv1d(
#               256, 256, kernel_size=(11,), stride=(1,), padding=(15,), dilation=(3,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#             (2): ParametrizedConv1d(
#               256, 256, kernel_size=(11,), stride=(1,), padding=(25,), dilation=(5,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#           (convs2): ModuleList(
#             (0-2): 3 x ParametrizedConv1d(
#               256, 256, kernel_size=(11,), stride=(1,), padding=(5,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#         )
#         (3): ResBlock1(
#           (convs1): ModuleList(
#             (0): ParametrizedConv1d(
#               128, 128, kernel_size=(3,), stride=(1,), padding=(1,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#             (1): ParametrizedConv1d(
#               128, 128, kernel_size=(3,), stride=(1,), padding=(3,), dilation=(3,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#             (2): ParametrizedConv1d(
#               128, 128, kernel_size=(3,), stride=(1,), padding=(5,), dilation=(5,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#           (convs2): ModuleList(
#             (0-2): 3 x ParametrizedConv1d(
#               128, 128, kernel_size=(3,), stride=(1,), padding=(1,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#         )
#         (4): ResBlock1(
#           (convs1): ModuleList(
#             (0): ParametrizedConv1d(
#               128, 128, kernel_size=(7,), stride=(1,), padding=(3,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#             (1): ParametrizedConv1d(
#               128, 128, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#             (2): ParametrizedConv1d(
#               128, 128, kernel_size=(7,), stride=(1,), padding=(15,), dilation=(5,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#           (convs2): ModuleList(
#             (0-2): 3 x ParametrizedConv1d(
#               128, 128, kernel_size=(7,), stride=(1,), padding=(3,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#         )
#         (5): ResBlock1(
#           (convs1): ModuleList(
#             (0): ParametrizedConv1d(
#               128, 128, kernel_size=(11,), stride=(1,), padding=(5,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#             (1): ParametrizedConv1d(
#               128, 128, kernel_size=(11,), stride=(1,), padding=(15,), dilation=(3,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#             (2): ParametrizedConv1d(
#               128, 128, kernel_size=(11,), stride=(1,), padding=(25,), dilation=(5,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#           (convs2): ModuleList(
#             (0-2): 3 x ParametrizedConv1d(
#               128, 128, kernel_size=(11,), stride=(1,), padding=(5,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#         )
#         (6): ResBlock1(
#           (convs1): ModuleList(
#             (0): ParametrizedConv1d(
#               64, 64, kernel_size=(3,), stride=(1,), padding=(1,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#             (1): ParametrizedConv1d(
#               64, 64, kernel_size=(3,), stride=(1,), padding=(3,), dilation=(3,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#             (2): ParametrizedConv1d(
#               64, 64, kernel_size=(3,), stride=(1,), padding=(5,), dilation=(5,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#           (convs2): ModuleList(
#             (0-2): 3 x ParametrizedConv1d(
#               64, 64, kernel_size=(3,), stride=(1,), padding=(1,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#         )
#         (7): ResBlock1(
#           (convs1): ModuleList(
#             (0): ParametrizedConv1d(
#               64, 64, kernel_size=(7,), stride=(1,), padding=(3,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#             (1): ParametrizedConv1d(
#               64, 64, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#             (2): ParametrizedConv1d(
#               64, 64, kernel_size=(7,), stride=(1,), padding=(15,), dilation=(5,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#           (convs2): ModuleList(
#             (0-2): 3 x ParametrizedConv1d(
#               64, 64, kernel_size=(7,), stride=(1,), padding=(3,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#         )
#         (8): ResBlock1(
#           (convs1): ModuleList(
#             (0): ParametrizedConv1d(
#               64, 64, kernel_size=(11,), stride=(1,), padding=(5,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#             (1): ParametrizedConv1d(
#               64, 64, kernel_size=(11,), stride=(1,), padding=(15,), dilation=(3,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#             (2): ParametrizedConv1d(
#               64, 64, kernel_size=(11,), stride=(1,), padding=(25,), dilation=(5,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#           (convs2): ModuleList(
#             (0-2): 3 x ParametrizedConv1d(
#               64, 64, kernel_size=(11,), stride=(1,), padding=(5,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#         )
#         (9): ResBlock1(
#           (convs1): ModuleList(
#             (0): ParametrizedConv1d(
#               32, 32, kernel_size=(3,), stride=(1,), padding=(1,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#             (1): ParametrizedConv1d(
#               32, 32, kernel_size=(3,), stride=(1,), padding=(3,), dilation=(3,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#             (2): ParametrizedConv1d(
#               32, 32, kernel_size=(3,), stride=(1,), padding=(5,), dilation=(5,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#           (convs2): ModuleList(
#             (0-2): 3 x ParametrizedConv1d(
#               32, 32, kernel_size=(3,), stride=(1,), padding=(1,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#         )
#         (10): ResBlock1(
#           (convs1): ModuleList(
#             (0): ParametrizedConv1d(
#               32, 32, kernel_size=(7,), stride=(1,), padding=(3,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#             (1): ParametrizedConv1d(
#               32, 32, kernel_size=(7,), stride=(1,), padding=(9,), dilation=(3,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#             (2): ParametrizedConv1d(
#               32, 32, kernel_size=(7,), stride=(1,), padding=(15,), dilation=(5,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#           (convs2): ModuleList(
#             (0-2): 3 x ParametrizedConv1d(
#               32, 32, kernel_size=(7,), stride=(1,), padding=(3,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#         )
#         (11): ResBlock1(
#           (convs1): ModuleList(
#             (0): ParametrizedConv1d(
#               32, 32, kernel_size=(11,), stride=(1,), padding=(5,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#             (1): ParametrizedConv1d(
#               32, 32, kernel_size=(11,), stride=(1,), padding=(15,), dilation=(3,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#             (2): ParametrizedConv1d(
#               32, 32, kernel_size=(11,), stride=(1,), padding=(25,), dilation=(5,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#           (convs2): ModuleList(
#             (0-2): 3 x ParametrizedConv1d(
#               32, 32, kernel_size=(11,), stride=(1,), padding=(5,)
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): _WeightNorm()
#                 )
#               )
#             )
#           )
#         )
#       )
#       (conv_post): Conv1d(32, 1, kernel_size=(7,), stride=(1,), padding=(3,), bias=False)
#       (cond_layer): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#       (conds): ModuleList(
#         (0): Conv1d(512, 256, kernel_size=(1,), stride=(1,))
#         (1): Conv1d(512, 128, kernel_size=(1,), stride=(1,))
#         (2): Conv1d(512, 64, kernel_size=(1,), stride=(1,))
#         (3): Conv1d(512, 32, kernel_size=(1,), stride=(1,))
#       )
#     )
#     (speaker_encoder): ResNetSpeakerEncoder(
#       (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu): ReLU(inplace=True)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (layer1): Sequential(
#         (0): SEBasicBlock(
#           (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=32, out_features=4, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=4, out_features=32, bias=True)
#               (3): Sigmoid()
#             )
#           )
#         )
#         (1): SEBasicBlock(
#           (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=32, out_features=4, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=4, out_features=32, bias=True)
#               (3): Sigmoid()
#             )
#           )
#         )
#         (2): SEBasicBlock(
#           (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=32, out_features=4, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=4, out_features=32, bias=True)
#               (3): Sigmoid()
#             )
#           )
#         )
#       )
#       (layer2): Sequential(
#         (0): SEBasicBlock(
#           (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=64, out_features=8, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=8, out_features=64, bias=True)
#               (3): Sigmoid()
#             )
#           )
#           (downsample): Sequential(
#             (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): SEBasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=64, out_features=8, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=8, out_features=64, bias=True)
#               (3): Sigmoid()
#             )
#           )
#         )
#         (2): SEBasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=64, out_features=8, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=8, out_features=64, bias=True)
#               (3): Sigmoid()
#             )
#           )
#         )
#         (3): SEBasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=64, out_features=8, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=8, out_features=64, bias=True)
#               (3): Sigmoid()
#             )
#           )
#         )
#       )
#       (layer3): Sequential(
#         (0): SEBasicBlock(
#           (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=128, out_features=16, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=16, out_features=128, bias=True)
#               (3): Sigmoid()
#             )
#           )
#           (downsample): Sequential(
#             (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): SEBasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=128, out_features=16, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=16, out_features=128, bias=True)
#               (3): Sigmoid()
#             )
#           )
#         )
#         (2): SEBasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=128, out_features=16, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=16, out_features=128, bias=True)
#               (3): Sigmoid()
#             )
#           )
#         )
#         (3): SEBasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=128, out_features=16, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=16, out_features=128, bias=True)
#               (3): Sigmoid()
#             )
#           )
#         )
#         (4): SEBasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=128, out_features=16, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=16, out_features=128, bias=True)
#               (3): Sigmoid()
#             )
#           )
#         )
#         (5): SEBasicBlock(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=128, out_features=16, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=16, out_features=128, bias=True)
#               (3): Sigmoid()
#             )
#           )
#         )
#       )
#       (layer4): Sequential(
#         (0): SEBasicBlock(
#           (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=256, out_features=32, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=32, out_features=256, bias=True)
#               (3): Sigmoid()
#             )
#           )
#           (downsample): Sequential(
#             (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): SEBasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=256, out_features=32, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=32, out_features=256, bias=True)
#               (3): Sigmoid()
#             )
#           )
#         )
#         (2): SEBasicBlock(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=256, out_features=32, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=32, out_features=256, bias=True)
#               (3): Sigmoid()
#             )
#           )
#         )
#       )
#       (instancenorm): InstanceNorm1d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (torch_spec): Sequential(
#         (0): PreEmphasis()
#         (1): MelSpectrogram(
#           (spectrogram): Spectrogram()
#           (mel_scale): MelScale()
#         )
#       )
#       (attention): Sequential(
#         (0): Conv1d(2048, 128, kernel_size=(1,), stride=(1,))
#         (1): ReLU()
#         (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): Conv1d(128, 2048, kernel_size=(1,), stride=(1,))
#         (4): Softmax(dim=2)
#       )
#       (fc): Linear(in_features=4096, out_features=512, bias=True)
#     )
#   )
# )

# %%
print("Computing speaker latents...")
gpt_cond_latent, speaker_embedding = model.get_conditioning_latents(
    audio_path=["./datasets/wavs/2_audio.wav"]
)


print("Inference...")
out = model.inference(
    "이거 모델 왜 지랄났냐 똑바로 안되냐!",
    "ko",
    gpt_cond_latent,
    speaker_embedding,
    temperature=0.7
)
torchaudio.save("./output.wav", torch.tensor(out["wav"]).unsqueeze(0), 24000)
# Out:
# Computing speaker latents...
# Inference...

# %%
# !CUDA_VISIBLE_DEVICES="0" python3 /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/TTS/bin/train_tts.py \
    --config_path /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/config.json \
    --restore_path /home/pengejeen/.local/share/tts/tts_models--es--mai--tacotron2-DDC/model_file.pth \
# Out:
#  | > Found 386 files in /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/datasets
#  > Using model: glow_tts
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:True
#  | > symmetric_norm:True
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:1.0
#  | > pitch_fmax:640.0
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:45
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Training Environment:
#  | > Backend: Torch
#  | > Mixed precision: False
#  | > Precision: float32
#  | > Current device: 0
#  | > Num. of GPUs: 1
#  | > Num. of CPUs: 12
#  | > Num. of Torch Threads: 6
#  | > Torch seed: 54321
#  | > Torch CUDNN: True
#  | > Torch CUDNN deterministic: False
#  | > Torch CUDNN benchmark: False
#  | > Torch TF32 MatMul: False
#  > Start Tensorboard: tensorboard --logdir=./paimon_ko/paimon_ko-May-23-2024_10+01PM-64158d0
#  > Restoring from model_file.pth ...
#  > Restoring Model...
#  > Partial model initialization...
#  | > Layer missing in the model definition: embedding.weight
#  | > Layer missing in the model definition: encoder.convolutions.0.convolution1d.weight
#  | > Layer missing in the model definition: encoder.convolutions.0.convolution1d.bias
#  | > Layer missing in the model definition: encoder.convolutions.0.batch_normalization.weight
#  | > Layer missing in the model definition: encoder.convolutions.0.batch_normalization.bias
#  | > Layer missing in the model definition: encoder.convolutions.0.batch_normalization.running_mean
#  | > Layer missing in the model definition: encoder.convolutions.0.batch_normalization.running_var
#  | > Layer missing in the model definition: encoder.convolutions.0.batch_normalization.num_batches_tracked
#  | > Layer missing in the model definition: encoder.convolutions.1.convolution1d.weight
#  | > Layer missing in the model definition: encoder.convolutions.1.convolution1d.bias
#  | > Layer missing in the model definition: encoder.convolutions.1.batch_normalization.weight
#  | > Layer missing in the model definition: encoder.convolutions.1.batch_normalization.bias
#  | > Layer missing in the model definition: encoder.convolutions.1.batch_normalization.running_mean
#  | > Layer missing in the model definition: encoder.convolutions.1.batch_normalization.running_var
#  | > Layer missing in the model definition: encoder.convolutions.1.batch_normalization.num_batches_tracked
#  | > Layer missing in the model definition: encoder.convolutions.2.convolution1d.weight
#  | > Layer missing in the model definition: encoder.convolutions.2.convolution1d.bias
#  | > Layer missing in the model definition: encoder.convolutions.2.batch_normalization.weight
#  | > Layer missing in the model definition: encoder.convolutions.2.batch_normalization.bias
#  | > Layer missing in the model definition: encoder.convolutions.2.batch_normalization.running_mean
#  | > Layer missing in the model definition: encoder.convolutions.2.batch_normalization.running_var
#  | > Layer missing in the model definition: encoder.convolutions.2.batch_normalization.num_batches_tracked
#  | > Layer missing in the model definition: encoder.lstm.weight_ih_l0
#  | > Layer missing in the model definition: encoder.lstm.weight_hh_l0
#  | > Layer missing in the model definition: encoder.lstm.bias_ih_l0
#  | > Layer missing in the model definition: encoder.lstm.bias_hh_l0
#  | > Layer missing in the model definition: encoder.lstm.weight_ih_l0_reverse
#  | > Layer missing in the model definition: encoder.lstm.weight_hh_l0_reverse
#  | > Layer missing in the model definition: encoder.lstm.bias_ih_l0_reverse
#  | > Layer missing in the model definition: encoder.lstm.bias_hh_l0_reverse
#  | > Layer missing in the model definition: decoder.prenet.linear_layers.0.linear_layer.weight
#  | > Layer missing in the model definition: decoder.prenet.linear_layers.1.linear_layer.weight
#  | > Layer missing in the model definition: decoder.attention_rnn.weight_ih
#  | > Layer missing in the model definition: decoder.attention_rnn.weight_hh
#  | > Layer missing in the model definition: decoder.attention_rnn.bias_ih
#  | > Layer missing in the model definition: decoder.attention_rnn.bias_hh
#  | > Layer missing in the model definition: decoder.attention.query_layer.linear_layer.weight
#  | > Layer missing in the model definition: decoder.attention.inputs_layer.linear_layer.weight
#  | > Layer missing in the model definition: decoder.attention.v.linear_layer.weight
#  | > Layer missing in the model definition: decoder.attention.v.linear_layer.bias
#  | > Layer missing in the model definition: decoder.attention.location_layer.location_conv1d.weight
#  | > Layer missing in the model definition: decoder.attention.location_layer.location_dense.linear_layer.weight
#  | > Layer missing in the model definition: decoder.decoder_rnn.weight_ih
#  | > Layer missing in the model definition: decoder.decoder_rnn.weight_hh
#  | > Layer missing in the model definition: decoder.decoder_rnn.bias_ih
#  | > Layer missing in the model definition: decoder.decoder_rnn.bias_hh
#  | > Layer missing in the model definition: decoder.linear_projection.linear_layer.weight
#  | > Layer missing in the model definition: decoder.linear_projection.linear_layer.bias
#  | > Layer missing in the model definition: decoder.stopnet.1.linear_layer.weight
#  | > Layer missing in the model definition: decoder.stopnet.1.linear_layer.bias
#  | > Layer missing in the model definition: postnet.convolutions.0.convolution1d.weight
#  | > Layer missing in the model definition: postnet.convolutions.0.convolution1d.bias
#  | > Layer missing in the model definition: postnet.convolutions.0.batch_normalization.weight
#  | > Layer missing in the model definition: postnet.convolutions.0.batch_normalization.bias
#  | > Layer missing in the model definition: postnet.convolutions.0.batch_normalization.running_mean
#  | > Layer missing in the model definition: postnet.convolutions.0.batch_normalization.running_var
#  | > Layer missing in the model definition: postnet.convolutions.0.batch_normalization.num_batches_tracked
#  | > Layer missing in the model definition: postnet.convolutions.1.convolution1d.weight
#  | > Layer missing in the model definition: postnet.convolutions.1.convolution1d.bias
#  | > Layer missing in the model definition: postnet.convolutions.1.batch_normalization.weight
#  | > Layer missing in the model definition: postnet.convolutions.1.batch_normalization.bias
#  | > Layer missing in the model definition: postnet.convolutions.1.batch_normalization.running_mean
#  | > Layer missing in the model definition: postnet.convolutions.1.batch_normalization.running_var
#  | > Layer missing in the model definition: postnet.convolutions.1.batch_normalization.num_batches_tracked
#  | > Layer missing in the model definition: postnet.convolutions.2.convolution1d.weight
#  | > Layer missing in the model definition: postnet.convolutions.2.convolution1d.bias
#  | > Layer missing in the model definition: postnet.convolutions.2.batch_normalization.weight
#  | > Layer missing in the model definition: postnet.convolutions.2.batch_normalization.bias
#  | > Layer missing in the model definition: postnet.convolutions.2.batch_normalization.running_mean
#  | > Layer missing in the model definition: postnet.convolutions.2.batch_normalization.running_var
#  | > Layer missing in the model definition: postnet.convolutions.2.batch_normalization.num_batches_tracked
#  | > Layer missing in the model definition: postnet.convolutions.3.convolution1d.weight
#  | > Layer missing in the model definition: postnet.convolutions.3.convolution1d.bias
#  | > Layer missing in the model definition: postnet.convolutions.3.batch_normalization.weight
#  | > Layer missing in the model definition: postnet.convolutions.3.batch_normalization.bias
#  | > Layer missing in the model definition: postnet.convolutions.3.batch_normalization.running_mean
#  | > Layer missing in the model definition: postnet.convolutions.3.batch_normalization.running_var
#  | > Layer missing in the model definition: postnet.convolutions.3.batch_normalization.num_batches_tracked
#  | > Layer missing in the model definition: postnet.convolutions.4.convolution1d.weight
#  | > Layer missing in the model definition: postnet.convolutions.4.convolution1d.bias
#  | > Layer missing in the model definition: postnet.convolutions.4.batch_normalization.weight
#  | > Layer missing in the model definition: postnet.convolutions.4.batch_normalization.bias
#  | > Layer missing in the model definition: postnet.convolutions.4.batch_normalization.running_mean
#  | > Layer missing in the model definition: postnet.convolutions.4.batch_normalization.running_var
#  | > Layer missing in the model definition: postnet.convolutions.4.batch_normalization.num_batches_tracked
#  | > Layer missing in the model definition: coarse_decoder.prenet.linear_layers.0.linear_layer.weight
#  | > Layer missing in the model definition: coarse_decoder.prenet.linear_layers.1.linear_layer.weight
#  | > Layer missing in the model definition: coarse_decoder.attention_rnn.weight_ih
#  | > Layer missing in the model definition: coarse_decoder.attention_rnn.weight_hh
#  | > Layer missing in the model definition: coarse_decoder.attention_rnn.bias_ih
#  | > Layer missing in the model definition: coarse_decoder.attention_rnn.bias_hh
#  | > Layer missing in the model definition: coarse_decoder.attention.query_layer.linear_layer.weight
#  | > Layer missing in the model definition: coarse_decoder.attention.inputs_layer.linear_layer.weight
#  | > Layer missing in the model definition: coarse_decoder.attention.v.linear_layer.weight
#  | > Layer missing in the model definition: coarse_decoder.attention.v.linear_layer.bias
#  | > Layer missing in the model definition: coarse_decoder.attention.location_layer.location_conv1d.weight
#  | > Layer missing in the model definition: coarse_decoder.attention.location_layer.location_dense.linear_layer.weight
#  | > Layer missing in the model definition: coarse_decoder.decoder_rnn.weight_ih
#  | > Layer missing in the model definition: coarse_decoder.decoder_rnn.weight_hh
#  | > Layer missing in the model definition: coarse_decoder.decoder_rnn.bias_ih
#  | > Layer missing in the model definition: coarse_decoder.decoder_rnn.bias_hh
#  | > Layer missing in the model definition: coarse_decoder.linear_projection.linear_layer.weight
#  | > Layer missing in the model definition: coarse_decoder.linear_projection.linear_layer.bias
#  | > Layer missing in the model definition: coarse_decoder.stopnet.1.linear_layer.weight
#  | > Layer missing in the model definition: coarse_decoder.stopnet.1.linear_layer.bias
#  | > Layer missing in the checkpoint: encoder.emb.weight
#  | > Layer missing in the checkpoint: encoder.prenet.conv_layers.0.weight
#  | > Layer missing in the checkpoint: encoder.prenet.conv_layers.0.bias
#  | > Layer missing in the checkpoint: encoder.prenet.conv_layers.1.weight
#  | > Layer missing in the checkpoint: encoder.prenet.conv_layers.1.bias
#  | > Layer missing in the checkpoint: encoder.prenet.conv_layers.2.weight
#  | > Layer missing in the checkpoint: encoder.prenet.conv_layers.2.bias
#  | > Layer missing in the checkpoint: encoder.prenet.norm_layers.0.gamma
#  | > Layer missing in the checkpoint: encoder.prenet.norm_layers.0.beta
#  | > Layer missing in the checkpoint: encoder.prenet.norm_layers.1.gamma
#  | > Layer missing in the checkpoint: encoder.prenet.norm_layers.1.beta
#  | > Layer missing in the checkpoint: encoder.prenet.norm_layers.2.gamma
#  | > Layer missing in the checkpoint: encoder.prenet.norm_layers.2.beta
#  | > Layer missing in the checkpoint: encoder.prenet.proj.weight
#  | > Layer missing in the checkpoint: encoder.prenet.proj.bias
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.0.conv_q.weight
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.0.conv_q.bias
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.0.conv_k.weight
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.0.conv_k.bias
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.0.conv_v.weight
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.0.conv_v.bias
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.0.conv_o.weight
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.0.conv_o.bias
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.1.conv_q.weight
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.1.conv_q.bias
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.1.conv_k.weight
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.1.conv_k.bias
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.1.conv_v.weight
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.1.conv_v.bias
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.1.conv_o.weight
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.1.conv_o.bias
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.2.conv_q.weight
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.2.conv_q.bias
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.2.conv_k.weight
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.2.conv_k.bias
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.2.conv_v.weight
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.2.conv_v.bias
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.2.conv_o.weight
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.2.conv_o.bias
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.3.conv_q.weight
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.3.conv_q.bias
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.3.conv_k.weight
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.3.conv_k.bias
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.3.conv_v.weight
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.3.conv_v.bias
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.3.conv_o.weight
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.3.conv_o.bias
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.4.conv_q.weight
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.4.conv_q.bias
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.4.conv_k.weight
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.4.conv_k.bias
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.4.conv_v.weight
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.4.conv_v.bias
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.4.conv_o.weight
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.4.conv_o.bias
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.5.conv_q.weight
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.5.conv_q.bias
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.5.conv_k.weight
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.5.conv_k.bias
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.5.conv_v.weight
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.5.conv_v.bias
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.5.conv_o.weight
#  | > Layer missing in the checkpoint: encoder.encoder.attn_layers.5.conv_o.bias
#  | > Layer missing in the checkpoint: encoder.encoder.norm_layers_1.0.gamma
#  | > Layer missing in the checkpoint: encoder.encoder.norm_layers_1.0.beta
#  | > Layer missing in the checkpoint: encoder.encoder.norm_layers_1.1.gamma
#  | > Layer missing in the checkpoint: encoder.encoder.norm_layers_1.1.beta
#  | > Layer missing in the checkpoint: encoder.encoder.norm_layers_1.2.gamma
#  | > Layer missing in the checkpoint: encoder.encoder.norm_layers_1.2.beta
#  | > Layer missing in the checkpoint: encoder.encoder.norm_layers_1.3.gamma
#  | > Layer missing in the checkpoint: encoder.encoder.norm_layers_1.3.beta
#  | > Layer missing in the checkpoint: encoder.encoder.norm_layers_1.4.gamma
#  | > Layer missing in the checkpoint: encoder.encoder.norm_layers_1.4.beta
#  | > Layer missing in the checkpoint: encoder.encoder.norm_layers_1.5.gamma
#  | > Layer missing in the checkpoint: encoder.encoder.norm_layers_1.5.beta
#  | > Layer missing in the checkpoint: encoder.encoder.ffn_layers.0.conv_1.weight
#  | > Layer missing in the checkpoint: encoder.encoder.ffn_layers.0.conv_1.bias
#  | > Layer missing in the checkpoint: encoder.encoder.ffn_layers.0.conv_2.weight
#  | > Layer missing in the checkpoint: encoder.encoder.ffn_layers.0.conv_2.bias
#  | > Layer missing in the checkpoint: encoder.encoder.ffn_layers.1.conv_1.weight
#  | > Layer missing in the checkpoint: encoder.encoder.ffn_layers.1.conv_1.bias
#  | > Layer missing in the checkpoint: encoder.encoder.ffn_layers.1.conv_2.weight
#  | > Layer missing in the checkpoint: encoder.encoder.ffn_layers.1.conv_2.bias
#  | > Layer missing in the checkpoint: encoder.encoder.ffn_layers.2.conv_1.weight
#  | > Layer missing in the checkpoint: encoder.encoder.ffn_layers.2.conv_1.bias
#  | > Layer missing in the checkpoint: encoder.encoder.ffn_layers.2.conv_2.weight
#  | > Layer missing in the checkpoint: encoder.encoder.ffn_layers.2.conv_2.bias
#  | > Layer missing in the checkpoint: encoder.encoder.ffn_layers.3.conv_1.weight
#  | > Layer missing in the checkpoint: encoder.encoder.ffn_layers.3.conv_1.bias
#  | > Layer missing in the checkpoint: encoder.encoder.ffn_layers.3.conv_2.weight
#  | > Layer missing in the checkpoint: encoder.encoder.ffn_layers.3.conv_2.bias
#  | > Layer missing in the checkpoint: encoder.encoder.ffn_layers.4.conv_1.weight
#  | > Layer missing in the checkpoint: encoder.encoder.ffn_layers.4.conv_1.bias
#  | > Layer missing in the checkpoint: encoder.encoder.ffn_layers.4.conv_2.weight
#  | > Layer missing in the checkpoint: encoder.encoder.ffn_layers.4.conv_2.bias
#  | > Layer missing in the checkpoint: encoder.encoder.ffn_layers.5.conv_1.weight
#  | > Layer missing in the checkpoint: encoder.encoder.ffn_layers.5.conv_1.bias
#  | > Layer missing in the checkpoint: encoder.encoder.ffn_layers.5.conv_2.weight
#  | > Layer missing in the checkpoint: encoder.encoder.ffn_layers.5.conv_2.bias
#  | > Layer missing in the checkpoint: encoder.encoder.norm_layers_2.0.gamma
#  | > Layer missing in the checkpoint: encoder.encoder.norm_layers_2.0.beta
#  | > Layer missing in the checkpoint: encoder.encoder.norm_layers_2.1.gamma
#  | > Layer missing in the checkpoint: encoder.encoder.norm_layers_2.1.beta
#  | > Layer missing in the checkpoint: encoder.encoder.norm_layers_2.2.gamma
#  | > Layer missing in the checkpoint: encoder.encoder.norm_layers_2.2.beta
#  | > Layer missing in the checkpoint: encoder.encoder.norm_layers_2.3.gamma
#  | > Layer missing in the checkpoint: encoder.encoder.norm_layers_2.3.beta
#  | > Layer missing in the checkpoint: encoder.encoder.norm_layers_2.4.gamma
#  | > Layer missing in the checkpoint: encoder.encoder.norm_layers_2.4.beta
#  | > Layer missing in the checkpoint: encoder.encoder.norm_layers_2.5.gamma
#  | > Layer missing in the checkpoint: encoder.encoder.norm_layers_2.5.beta
#  | > Layer missing in the checkpoint: encoder.proj_m.weight
#  | > Layer missing in the checkpoint: encoder.proj_m.bias
#  | > Layer missing in the checkpoint: encoder.duration_predictor.conv_1.weight
#  | > Layer missing in the checkpoint: encoder.duration_predictor.conv_1.bias
#  | > Layer missing in the checkpoint: encoder.duration_predictor.norm_1.gamma
#  | > Layer missing in the checkpoint: encoder.duration_predictor.norm_1.beta
#  | > Layer missing in the checkpoint: encoder.duration_predictor.conv_2.weight
#  | > Layer missing in the checkpoint: encoder.duration_predictor.conv_2.bias
#  | > Layer missing in the checkpoint: encoder.duration_predictor.norm_2.gamma
#  | > Layer missing in the checkpoint: encoder.duration_predictor.norm_2.beta
#  | > Layer missing in the checkpoint: encoder.duration_predictor.proj.weight
#  | > Layer missing in the checkpoint: encoder.duration_predictor.proj.bias
#  | > Layer missing in the checkpoint: decoder.flows.0.logs
#  | > Layer missing in the checkpoint: decoder.flows.0.bias
#  | > Layer missing in the checkpoint: decoder.flows.1.weight
#  | > Layer missing in the checkpoint: decoder.flows.2.start.bias
#  | > Layer missing in the checkpoint: decoder.flows.2.start.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.2.start.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.2.end.weight
#  | > Layer missing in the checkpoint: decoder.flows.2.end.bias
#  | > Layer missing in the checkpoint: decoder.flows.2.wn.in_layers.0.bias
#  | > Layer missing in the checkpoint: decoder.flows.2.wn.in_layers.0.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.2.wn.in_layers.0.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.2.wn.in_layers.1.bias
#  | > Layer missing in the checkpoint: decoder.flows.2.wn.in_layers.1.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.2.wn.in_layers.1.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.2.wn.in_layers.2.bias
#  | > Layer missing in the checkpoint: decoder.flows.2.wn.in_layers.2.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.2.wn.in_layers.2.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.2.wn.in_layers.3.bias
#  | > Layer missing in the checkpoint: decoder.flows.2.wn.in_layers.3.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.2.wn.in_layers.3.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.2.wn.res_skip_layers.0.bias
#  | > Layer missing in the checkpoint: decoder.flows.2.wn.res_skip_layers.0.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.2.wn.res_skip_layers.0.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.2.wn.res_skip_layers.1.bias
#  | > Layer missing in the checkpoint: decoder.flows.2.wn.res_skip_layers.1.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.2.wn.res_skip_layers.1.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.2.wn.res_skip_layers.2.bias
#  | > Layer missing in the checkpoint: decoder.flows.2.wn.res_skip_layers.2.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.2.wn.res_skip_layers.2.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.2.wn.res_skip_layers.3.bias
#  | > Layer missing in the checkpoint: decoder.flows.2.wn.res_skip_layers.3.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.2.wn.res_skip_layers.3.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.3.logs
#  | > Layer missing in the checkpoint: decoder.flows.3.bias
#  | > Layer missing in the checkpoint: decoder.flows.4.weight
#  | > Layer missing in the checkpoint: decoder.flows.5.start.bias
#  | > Layer missing in the checkpoint: decoder.flows.5.start.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.5.start.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.5.end.weight
#  | > Layer missing in the checkpoint: decoder.flows.5.end.bias
#  | > Layer missing in the checkpoint: decoder.flows.5.wn.in_layers.0.bias
#  | > Layer missing in the checkpoint: decoder.flows.5.wn.in_layers.0.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.5.wn.in_layers.0.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.5.wn.in_layers.1.bias
#  | > Layer missing in the checkpoint: decoder.flows.5.wn.in_layers.1.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.5.wn.in_layers.1.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.5.wn.in_layers.2.bias
#  | > Layer missing in the checkpoint: decoder.flows.5.wn.in_layers.2.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.5.wn.in_layers.2.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.5.wn.in_layers.3.bias
#  | > Layer missing in the checkpoint: decoder.flows.5.wn.in_layers.3.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.5.wn.in_layers.3.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.5.wn.res_skip_layers.0.bias
#  | > Layer missing in the checkpoint: decoder.flows.5.wn.res_skip_layers.0.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.5.wn.res_skip_layers.0.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.5.wn.res_skip_layers.1.bias
#  | > Layer missing in the checkpoint: decoder.flows.5.wn.res_skip_layers.1.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.5.wn.res_skip_layers.1.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.5.wn.res_skip_layers.2.bias
#  | > Layer missing in the checkpoint: decoder.flows.5.wn.res_skip_layers.2.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.5.wn.res_skip_layers.2.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.5.wn.res_skip_layers.3.bias
#  | > Layer missing in the checkpoint: decoder.flows.5.wn.res_skip_layers.3.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.5.wn.res_skip_layers.3.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.6.logs
#  | > Layer missing in the checkpoint: decoder.flows.6.bias
#  | > Layer missing in the checkpoint: decoder.flows.7.weight
#  | > Layer missing in the checkpoint: decoder.flows.8.start.bias
#  | > Layer missing in the checkpoint: decoder.flows.8.start.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.8.start.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.8.end.weight
#  | > Layer missing in the checkpoint: decoder.flows.8.end.bias
#  | > Layer missing in the checkpoint: decoder.flows.8.wn.in_layers.0.bias
#  | > Layer missing in the checkpoint: decoder.flows.8.wn.in_layers.0.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.8.wn.in_layers.0.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.8.wn.in_layers.1.bias
#  | > Layer missing in the checkpoint: decoder.flows.8.wn.in_layers.1.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.8.wn.in_layers.1.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.8.wn.in_layers.2.bias
#  | > Layer missing in the checkpoint: decoder.flows.8.wn.in_layers.2.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.8.wn.in_layers.2.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.8.wn.in_layers.3.bias
#  | > Layer missing in the checkpoint: decoder.flows.8.wn.in_layers.3.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.8.wn.in_layers.3.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.8.wn.res_skip_layers.0.bias
#  | > Layer missing in the checkpoint: decoder.flows.8.wn.res_skip_layers.0.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.8.wn.res_skip_layers.0.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.8.wn.res_skip_layers.1.bias
#  | > Layer missing in the checkpoint: decoder.flows.8.wn.res_skip_layers.1.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.8.wn.res_skip_layers.1.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.8.wn.res_skip_layers.2.bias
#  | > Layer missing in the checkpoint: decoder.flows.8.wn.res_skip_layers.2.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.8.wn.res_skip_layers.2.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.8.wn.res_skip_layers.3.bias
#  | > Layer missing in the checkpoint: decoder.flows.8.wn.res_skip_layers.3.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.8.wn.res_skip_layers.3.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.9.logs
#  | > Layer missing in the checkpoint: decoder.flows.9.bias
#  | > Layer missing in the checkpoint: decoder.flows.10.weight
#  | > Layer missing in the checkpoint: decoder.flows.11.start.bias
#  | > Layer missing in the checkpoint: decoder.flows.11.start.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.11.start.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.11.end.weight
#  | > Layer missing in the checkpoint: decoder.flows.11.end.bias
#  | > Layer missing in the checkpoint: decoder.flows.11.wn.in_layers.0.bias
#  | > Layer missing in the checkpoint: decoder.flows.11.wn.in_layers.0.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.11.wn.in_layers.0.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.11.wn.in_layers.1.bias
#  | > Layer missing in the checkpoint: decoder.flows.11.wn.in_layers.1.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.11.wn.in_layers.1.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.11.wn.in_layers.2.bias
#  | > Layer missing in the checkpoint: decoder.flows.11.wn.in_layers.2.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.11.wn.in_layers.2.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.11.wn.in_layers.3.bias
#  | > Layer missing in the checkpoint: decoder.flows.11.wn.in_layers.3.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.11.wn.in_layers.3.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.11.wn.res_skip_layers.0.bias
#  | > Layer missing in the checkpoint: decoder.flows.11.wn.res_skip_layers.0.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.11.wn.res_skip_layers.0.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.11.wn.res_skip_layers.1.bias
#  | > Layer missing in the checkpoint: decoder.flows.11.wn.res_skip_layers.1.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.11.wn.res_skip_layers.1.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.11.wn.res_skip_layers.2.bias
#  | > Layer missing in the checkpoint: decoder.flows.11.wn.res_skip_layers.2.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.11.wn.res_skip_layers.2.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.11.wn.res_skip_layers.3.bias
#  | > Layer missing in the checkpoint: decoder.flows.11.wn.res_skip_layers.3.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.11.wn.res_skip_layers.3.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.12.logs
#  | > Layer missing in the checkpoint: decoder.flows.12.bias
#  | > Layer missing in the checkpoint: decoder.flows.13.weight
#  | > Layer missing in the checkpoint: decoder.flows.14.start.bias
#  | > Layer missing in the checkpoint: decoder.flows.14.start.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.14.start.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.14.end.weight
#  | > Layer missing in the checkpoint: decoder.flows.14.end.bias
#  | > Layer missing in the checkpoint: decoder.flows.14.wn.in_layers.0.bias
#  | > Layer missing in the checkpoint: decoder.flows.14.wn.in_layers.0.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.14.wn.in_layers.0.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.14.wn.in_layers.1.bias
#  | > Layer missing in the checkpoint: decoder.flows.14.wn.in_layers.1.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.14.wn.in_layers.1.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.14.wn.in_layers.2.bias
#  | > Layer missing in the checkpoint: decoder.flows.14.wn.in_layers.2.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.14.wn.in_layers.2.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.14.wn.in_layers.3.bias
#  | > Layer missing in the checkpoint: decoder.flows.14.wn.in_layers.3.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.14.wn.in_layers.3.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.14.wn.res_skip_layers.0.bias
#  | > Layer missing in the checkpoint: decoder.flows.14.wn.res_skip_layers.0.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.14.wn.res_skip_layers.0.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.14.wn.res_skip_layers.1.bias
#  | > Layer missing in the checkpoint: decoder.flows.14.wn.res_skip_layers.1.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.14.wn.res_skip_layers.1.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.14.wn.res_skip_layers.2.bias
#  | > Layer missing in the checkpoint: decoder.flows.14.wn.res_skip_layers.2.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.14.wn.res_skip_layers.2.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.14.wn.res_skip_layers.3.bias
#  | > Layer missing in the checkpoint: decoder.flows.14.wn.res_skip_layers.3.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.14.wn.res_skip_layers.3.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.15.logs
#  | > Layer missing in the checkpoint: decoder.flows.15.bias
#  | > Layer missing in the checkpoint: decoder.flows.16.weight
#  | > Layer missing in the checkpoint: decoder.flows.17.start.bias
#  | > Layer missing in the checkpoint: decoder.flows.17.start.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.17.start.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.17.end.weight
#  | > Layer missing in the checkpoint: decoder.flows.17.end.bias
#  | > Layer missing in the checkpoint: decoder.flows.17.wn.in_layers.0.bias
#  | > Layer missing in the checkpoint: decoder.flows.17.wn.in_layers.0.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.17.wn.in_layers.0.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.17.wn.in_layers.1.bias
#  | > Layer missing in the checkpoint: decoder.flows.17.wn.in_layers.1.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.17.wn.in_layers.1.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.17.wn.in_layers.2.bias
#  | > Layer missing in the checkpoint: decoder.flows.17.wn.in_layers.2.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.17.wn.in_layers.2.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.17.wn.in_layers.3.bias
#  | > Layer missing in the checkpoint: decoder.flows.17.wn.in_layers.3.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.17.wn.in_layers.3.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.17.wn.res_skip_layers.0.bias
#  | > Layer missing in the checkpoint: decoder.flows.17.wn.res_skip_layers.0.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.17.wn.res_skip_layers.0.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.17.wn.res_skip_layers.1.bias
#  | > Layer missing in the checkpoint: decoder.flows.17.wn.res_skip_layers.1.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.17.wn.res_skip_layers.1.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.17.wn.res_skip_layers.2.bias
#  | > Layer missing in the checkpoint: decoder.flows.17.wn.res_skip_layers.2.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.17.wn.res_skip_layers.2.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.17.wn.res_skip_layers.3.bias
#  | > Layer missing in the checkpoint: decoder.flows.17.wn.res_skip_layers.3.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.17.wn.res_skip_layers.3.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.18.logs
#  | > Layer missing in the checkpoint: decoder.flows.18.bias
#  | > Layer missing in the checkpoint: decoder.flows.19.weight
#  | > Layer missing in the checkpoint: decoder.flows.20.start.bias
#  | > Layer missing in the checkpoint: decoder.flows.20.start.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.20.start.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.20.end.weight
#  | > Layer missing in the checkpoint: decoder.flows.20.end.bias
#  | > Layer missing in the checkpoint: decoder.flows.20.wn.in_layers.0.bias
#  | > Layer missing in the checkpoint: decoder.flows.20.wn.in_layers.0.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.20.wn.in_layers.0.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.20.wn.in_layers.1.bias
#  | > Layer missing in the checkpoint: decoder.flows.20.wn.in_layers.1.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.20.wn.in_layers.1.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.20.wn.in_layers.2.bias
#  | > Layer missing in the checkpoint: decoder.flows.20.wn.in_layers.2.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.20.wn.in_layers.2.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.20.wn.in_layers.3.bias
#  | > Layer missing in the checkpoint: decoder.flows.20.wn.in_layers.3.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.20.wn.in_layers.3.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.20.wn.res_skip_layers.0.bias
#  | > Layer missing in the checkpoint: decoder.flows.20.wn.res_skip_layers.0.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.20.wn.res_skip_layers.0.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.20.wn.res_skip_layers.1.bias
#  | > Layer missing in the checkpoint: decoder.flows.20.wn.res_skip_layers.1.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.20.wn.res_skip_layers.1.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.20.wn.res_skip_layers.2.bias
#  | > Layer missing in the checkpoint: decoder.flows.20.wn.res_skip_layers.2.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.20.wn.res_skip_layers.2.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.20.wn.res_skip_layers.3.bias
#  | > Layer missing in the checkpoint: decoder.flows.20.wn.res_skip_layers.3.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.20.wn.res_skip_layers.3.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.21.logs
#  | > Layer missing in the checkpoint: decoder.flows.21.bias
#  | > Layer missing in the checkpoint: decoder.flows.22.weight
#  | > Layer missing in the checkpoint: decoder.flows.23.start.bias
#  | > Layer missing in the checkpoint: decoder.flows.23.start.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.23.start.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.23.end.weight
#  | > Layer missing in the checkpoint: decoder.flows.23.end.bias
#  | > Layer missing in the checkpoint: decoder.flows.23.wn.in_layers.0.bias
#  | > Layer missing in the checkpoint: decoder.flows.23.wn.in_layers.0.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.23.wn.in_layers.0.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.23.wn.in_layers.1.bias
#  | > Layer missing in the checkpoint: decoder.flows.23.wn.in_layers.1.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.23.wn.in_layers.1.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.23.wn.in_layers.2.bias
#  | > Layer missing in the checkpoint: decoder.flows.23.wn.in_layers.2.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.23.wn.in_layers.2.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.23.wn.in_layers.3.bias
#  | > Layer missing in the checkpoint: decoder.flows.23.wn.in_layers.3.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.23.wn.in_layers.3.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.23.wn.res_skip_layers.0.bias
#  | > Layer missing in the checkpoint: decoder.flows.23.wn.res_skip_layers.0.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.23.wn.res_skip_layers.0.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.23.wn.res_skip_layers.1.bias
#  | > Layer missing in the checkpoint: decoder.flows.23.wn.res_skip_layers.1.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.23.wn.res_skip_layers.1.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.23.wn.res_skip_layers.2.bias
#  | > Layer missing in the checkpoint: decoder.flows.23.wn.res_skip_layers.2.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.23.wn.res_skip_layers.2.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.23.wn.res_skip_layers.3.bias
#  | > Layer missing in the checkpoint: decoder.flows.23.wn.res_skip_layers.3.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.23.wn.res_skip_layers.3.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.24.logs
#  | > Layer missing in the checkpoint: decoder.flows.24.bias
#  | > Layer missing in the checkpoint: decoder.flows.25.weight
#  | > Layer missing in the checkpoint: decoder.flows.26.start.bias
#  | > Layer missing in the checkpoint: decoder.flows.26.start.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.26.start.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.26.end.weight
#  | > Layer missing in the checkpoint: decoder.flows.26.end.bias
#  | > Layer missing in the checkpoint: decoder.flows.26.wn.in_layers.0.bias
#  | > Layer missing in the checkpoint: decoder.flows.26.wn.in_layers.0.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.26.wn.in_layers.0.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.26.wn.in_layers.1.bias
#  | > Layer missing in the checkpoint: decoder.flows.26.wn.in_layers.1.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.26.wn.in_layers.1.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.26.wn.in_layers.2.bias
#  | > Layer missing in the checkpoint: decoder.flows.26.wn.in_layers.2.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.26.wn.in_layers.2.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.26.wn.in_layers.3.bias
#  | > Layer missing in the checkpoint: decoder.flows.26.wn.in_layers.3.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.26.wn.in_layers.3.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.26.wn.res_skip_layers.0.bias
#  | > Layer missing in the checkpoint: decoder.flows.26.wn.res_skip_layers.0.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.26.wn.res_skip_layers.0.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.26.wn.res_skip_layers.1.bias
#  | > Layer missing in the checkpoint: decoder.flows.26.wn.res_skip_layers.1.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.26.wn.res_skip_layers.1.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.26.wn.res_skip_layers.2.bias
#  | > Layer missing in the checkpoint: decoder.flows.26.wn.res_skip_layers.2.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.26.wn.res_skip_layers.2.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.26.wn.res_skip_layers.3.bias
#  | > Layer missing in the checkpoint: decoder.flows.26.wn.res_skip_layers.3.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.26.wn.res_skip_layers.3.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.27.logs
#  | > Layer missing in the checkpoint: decoder.flows.27.bias
#  | > Layer missing in the checkpoint: decoder.flows.28.weight
#  | > Layer missing in the checkpoint: decoder.flows.29.start.bias
#  | > Layer missing in the checkpoint: decoder.flows.29.start.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.29.start.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.29.end.weight
#  | > Layer missing in the checkpoint: decoder.flows.29.end.bias
#  | > Layer missing in the checkpoint: decoder.flows.29.wn.in_layers.0.bias
#  | > Layer missing in the checkpoint: decoder.flows.29.wn.in_layers.0.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.29.wn.in_layers.0.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.29.wn.in_layers.1.bias
#  | > Layer missing in the checkpoint: decoder.flows.29.wn.in_layers.1.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.29.wn.in_layers.1.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.29.wn.in_layers.2.bias
#  | > Layer missing in the checkpoint: decoder.flows.29.wn.in_layers.2.parametrizations.weight.original0
#  | > Layer missing in the checkpoint: decoder.flows.29.wn.in_layers.2.parametrizations.weight.original1
#  | > Layer missing in the checkpoint: decoder.flows.29.wn.in_layers.3.bias
# ...
# 자, 잠깐, 마음의 준비가 필요해!
#
#  [!] Character '깐' not found in the vocabulary. Discarding it.
# 자, 잠깐, 마음의 준비가 필요해!
#
#  [!] Character '준' not found in the vocabulary. Discarding it.
# 자, 잠깐, 마음의 준비가 필요해!
#
#  [!] Character '필' not found in the vocabulary. Discarding it.
# 자, 잠깐, 마음의 준비가 필요해!
#
#  [!] Character '요' not found in the vocabulary. Discarding it.
# 그거 나 아니거든! 그게 어떻게 나냐구!
#
#  [!] Character '든' not found in the vocabulary. Discarding it.
# 그거 나 아니거든! 그게 어떻게 나냐구!
#
#  [!] Character '떻' not found in the vocabulary. Discarding it.
# 그거 나 아니거든! 그게 어떻게 나냐구!
#
#  [!] Character '냐' not found in the vocabulary. Discarding it.
# 힘들긴 했지만, 대단한 일을 한 기분이 들어!
#
#  [!] Character '힘' not found in the vocabulary. Discarding it.
# 힘들긴 했지만, 대단한 일을 한 기분이 들어!
#
#  [!] Character '긴' not found in the vocabulary. Discarding it.
# 힘들긴 했지만, 대단한 일을 한 기분이 들어!
#
#  [!] Character '했' not found in the vocabulary. Discarding it.
# 힘들긴 했지만, 대단한 일을 한 기분이 들어!
#
#  [!] Character '단' not found in the vocabulary. Discarding it.
# 힘들긴 했지만, 대단한 일을 한 기분이 들어!
#
#  [!] Character '일' not found in the vocabulary. Discarding it.
# 힘들긴 했지만, 대단한 일을 한 기분이 들어!
#
#  [!] Character '기' not found in the vocabulary. Discarding it.
# 흠… 언제까지 기다려야 효과가 나타날까?
#
#  [!] Character '흠' not found in the vocabulary. Discarding it.
# 흠… 언제까지 기다려야 효과가 나타날까?
#
#  [!] Character '언' not found in the vocabulary. Discarding it.
# 흠… 언제까지 기다려야 효과가 나타날까?
#
#  [!] Character '제' not found in the vocabulary. Discarding it.
# 흠… 언제까지 기다려야 효과가 나타날까?
#
#  [!] Character '효' not found in the vocabulary. Discarding it.
# 흠… 언제까지 기다려야 효과가 나타날까?
#
#  [!] Character '과' not found in the vocabulary. Discarding it.
# 흠… 언제까지 기다려야 효과가 나타날까?
#
#  [!] Character '타' not found in the vocabulary. Discarding it.
# 흠… 언제까지 기다려야 효과가 나타날까?
#
#  [!] Character '날' not found in the vocabulary. Discarding it.
# 응응, 모험에서의 경험을 활용할 수 있겠어
#
#  [!] Character '험' not found in the vocabulary. Discarding it.
# 응응, 모험에서의 경험을 활용할 수 있겠어
#
#  [!] Character '경' not found in the vocabulary. Discarding it.
# 응응, 모험에서의 경험을 활용할 수 있겠어
#
#  [!] Character '활' not found in the vocabulary. Discarding it.
# 응응, 모험에서의 경험을 활용할 수 있겠어
#
#  [!] Character '용' not found in the vocabulary. Discarding it.
# 응응, 모험에서의 경험을 활용할 수 있겠어
#
#  [!] Character '수' not found in the vocabulary. Discarding it.
# 참, 우리가 테스트하는 동안 넌 뭐 할 거야?
#
#  [!] Character '테' not found in the vocabulary. Discarding it.
# 참, 우리가 테스트하는 동안 넌 뭐 할 거야?
#
#  [!] Character '스' not found in the vocabulary. Discarding it.
# 참, 우리가 테스트하는 동안 넌 뭐 할 거야?
#
#  [!] Character '트' not found in the vocabulary. Discarding it.
# 참, 우리가 테스트하는 동안 넌 뭐 할 거야?
#
#  [!] Character '하' not found in the vocabulary. Discarding it.
# 참, 우리가 테스트하는 동안 넌 뭐 할 거야?
#
#  [!] Character '동' not found in the vocabulary. Discarding it.
# 참, 우리가 테스트하는 동안 넌 뭐 할 거야?
#
#  [!] Character '넌' not found in the vocabulary. Discarding it.
# 참, 우리가 테스트하는 동안 넌 뭐 할 거야?
#
#  [!] Character '할' not found in the vocabulary. Discarding it.
# 어? 미코! 그걸 네가 먼저 말하면 어떡해!
#
#  [!] Character '미' not found in the vocabulary. Discarding it.
# 어? 미코! 그걸 네가 먼저 말하면 어떡해!
#
#  [!] Character '코' not found in the vocabulary. Discarding it.
# 어? 미코! 그걸 네가 먼저 말하면 어떡해!
#
#  [!] Character '먼' not found in the vocabulary. Discarding it.
# 뭐라고! 방금 무슨 맛이라고!?
#
#
# 우와, 엄청 큰 물방울이야…
#
#  [!] Character '와' not found in the vocabulary. Discarding it.
# 우와, 엄청 큰 물방울이야…
#
#  [!] Character '방' not found in the vocabulary. Discarding it.
# 우와, 엄청 큰 물방울이야…
#
#  [!] Character '울' not found in the vocabulary. Discarding it.
#    --> TIME: 2024-05-23 22:02:26 -- STEP: 1/12 -- GLOBAL_STEP: 380050
#      | > loss: 14.171558380126953  (14.171558380126953)
#      | > log_mle: 2.5861470699310303  (2.5861470699310303)
#      | > loss_dur: 11.585411071777344  (11.585411071777344)
#      | > grad_norm: tensor(19.3467, device='cuda:0')  (tensor(19.3467, device='cuda:0'))
#      | > current_lr: 1e-06
#      | > step_time: 0.4489  (0.4488656520843506)
#      | > loader_time: 0.0191  (0.019066810607910156)
#
#  [!] Character '방' not found in the vocabulary. Discarding it.
# 뭐라고! 방금 무슨 맛이라고!?
#
#  [!] Character '금' not found in the vocabulary. Discarding it.
# 뭐라고! 방금 무슨 맛이라고!?
#
#  [!] Character '맛' not found in the vocabulary. Discarding it.
# 늑대는 아주 신비로워, 그렇게 자주 볼 수 있는 게 아니라구
#
#  [!] Character '늑' not found in the vocabulary. Discarding it.
# 늑대는 아주 신비로워, 그렇게 자주 볼 수 있는 게 아니라구
#
#  [!] Character '주' not found in the vocabulary. Discarding it.
# 늑대는 아주 신비로워, 그렇게 자주 볼 수 있는 게 아니라구
#
#  [!] Character '신' not found in the vocabulary. Discarding it.
# 늑대는 아주 신비로워, 그렇게 자주 볼 수 있는 게 아니라구
#
#  [!] Character '워' not found in the vocabulary. Discarding it.
# 늑대는 아주 신비로워, 그렇게 자주 볼 수 있는 게 아니라구
#
#  [!] Character '볼' not found in the vocabulary. Discarding it.
# 늑대는 아주 신비로워, 그렇게 자주 볼 수 있는 게 아니라구
#
#  [!] Character '니' not found in the vocabulary. Discarding it.
# #야! {NICKNAME}, 너 또 나 놀린 거야?!
# 「전선」에 엄청 집작하는 것 같네…
#
#  [!] Character '너' not found in the vocabulary. Discarding it.
# 어, 두지에랑 얘기가 다 끝났나 봐. 우리도 돌아가 보자
#
#  [!] Character '「' not found in the vocabulary. Discarding it.
# 「전선」에 엄청 집작하는 것 같네…
#
#  [!] Character '전' not found in the vocabulary. Discarding it.
# 「전선」에 엄청 집작하는 것 같네…
#
#  [!] Character '선' not found in the vocabulary. Discarding it.
# 「전선」에 엄청 집작하는 것 같네…
#
#  [!] Character '」' not found in the vocabulary. Discarding it.
# 「전선」에 엄청 집작하는 것 같네…
#
#  [!] Character '집' not found in the vocabulary. Discarding it.
# 「전선」에 엄청 집작하는 것 같네…
#
#  [!] Character '작' not found in the vocabulary. Discarding it.
#
#  [!] Character '끝' not found in the vocabulary. Discarding it.
# 어, 두지에랑 얘기가 다 끝났나 봐. 우리도 돌아가 보자
#
#  [!] Character '났' not found in the vocabulary. Discarding it.
# 어, 두지에랑 얘기가 다 끝났나 봐. 우리도 돌아가 보자
#
#  [!] Character '돌' not found in the vocabulary. Discarding it.
# 어, 두지에랑 얘기가 다 끝났나 봐. 우리도 돌아가 보자
#
#  [!] Character '보' not found in the vocabulary. Discarding it.
# 300만이랑 299만은 별 차이 없잖아?!
#
#  [!] Character '0' not found in the vocabulary. Discarding it.
# 300만이랑 299만은 별 차이 없잖아?!
#
#  [!] Character '별' not found in the vocabulary. Discarding it.
# 300만이랑 299만은 별 차이 없잖아?!
#
#  [!] Character '차' not found in the vocabulary. Discarding it.
# 300만이랑 299만은 별 차이 없잖아?!
#
#  [!] Character '잖' not found in the vocabulary. Discarding it.
# 후후, 빨리 공격해! 「슈퍼 페이몬 선풍」을 써!
#
#  [!] Character '후' not found in the vocabulary. Discarding it.
# 후후, 빨리 공격해! 「슈퍼 페이몬 선풍」을 써!
#
#  [!] Character '빨' not found in the vocabulary. Discarding it.
# 후후, 빨리 공격해! 「슈퍼 페이몬 선풍」을 써!
#
#  [!] Character '공' not found in the vocabulary. Discarding it.
# 후후, 빨리 공격해! 「슈퍼 페이몬 선풍」을 써!
#
#  [!] Character '격' not found in the vocabulary. Discarding it.
# 후후, 빨리 공격해! 「슈퍼 페이몬 선풍」을 써!
#
#  [!] Character '슈' not found in the vocabulary. Discarding it.
# 후후, 빨리 공격해! 「슈퍼 페이몬 선풍」을 써!
#
#  [!] Character '퍼' not found in the vocabulary. Discarding it.
# 후후, 빨리 공격해! 「슈퍼 페이몬 선풍」을 써!
#
#  [!] Character '써' not found in the vocabulary. Discarding it.
# 무슨 일이야? 상황이 급박하다고, 우리가…
#
#  [!] Character '상' not found in the vocabulary. Discarding it.
# 무슨 일이야? 상황이 급박하다고, 우리가…
#
#  [!] Character '황' not found in the vocabulary. Discarding it.
# 무슨 일이야? 상황이 급박하다고, 우리가…
#
#  [!] Character '급' not found in the vocabulary. Discarding it.
# 무슨 일이야? 상황이 급박하다고, 우리가…
#
#  [!] Character '박' not found in the vocabulary. Discarding it.
# #{F#오빠가}{M#동생이} 너무 보고 싶어서 순간적으로 생긴 환상인가?
#
#  [!] Character '빠' not found in the vocabulary. Discarding it.
# #{F#오빠가}{M#동생이} 너무 보고 싶어서 순간적으로 생긴 환상인가?
#
#  [!] Character '동' not found in the vocabulary. Discarding it.
# #{F#오빠가}{M#동생이} 너무 보고 싶어서 순간적으로 생긴 환상인가?
#
#  [!] Character '생' not found in the vocabulary. Discarding it.
# #{F#오빠가}{M#동생이} 너무 보고 싶어서 순간적으로 생긴 환상인가?
#
#  [!] Character '무' not found in the vocabulary. Discarding it.
# #{F#오빠가}{M#동생이} 너무 보고 싶어서 순간적으로 생긴 환상인가?
#
#  [!] Character '싶' not found in the vocabulary. Discarding it.
# #{F#오빠가}{M#동생이} 너무 보고 싶어서 순간적으로 생긴 환상인가?
#
#  [!] Character '순' not found in the vocabulary. Discarding it.
# #{F#오빠가}{M#동생이} 너무 보고 싶어서 순간적으로 생긴 환상인가?
#
#  [!] Character '간' not found in the vocabulary. Discarding it.
# #{F#오빠가}{M#동생이} 너무 보고 싶어서 순간적으로 생긴 환상인가?
#
#  [!] Character '긴' not found in the vocabulary. Discarding it.
# #{F#오빠가}{M#동생이} 너무 보고 싶어서 순간적으로 생긴 환상인가?
#
#  [!] Character '환' not found in the vocabulary. Discarding it.
# 근데 네가 이렇게까지 할 줄은 몰랐어…
#
#  [!] Character '근' not found in the vocabulary. Discarding it.
# 근데 네가 이렇게까지 할 줄은 몰랐어…
#
#  [!] Character '몰' not found in the vocabulary. Discarding it.
# 근데 네가 이렇게까지 할 줄은 몰랐어…
#
#  [!] Character '랐' not found in the vocabulary. Discarding it.
# 그럼 한시가 급하니 간다르바 성곽으로 바로 출발하자
#
#  [!] Character '급' not found in the vocabulary. Discarding it.
# 그럼 한시가 급하니 간다르바 성곽으로 바로 출발하자
#
#  [!] Character '간' not found in the vocabulary. Discarding it.
# 그럼 한시가 급하니 간다르바 성곽으로 바로 출발하자
#
#  [!] Character '바' not found in the vocabulary. Discarding it.
# 그럼 한시가 급하니 간다르바 성곽으로 바로 출발하자
#
#  [!] Character '곽' not found in the vocabulary. Discarding it.
# 그럼 한시가 급하니 간다르바 성곽으로 바로 출발하자
#
#  [!] Character '으' not found in the vocabulary. Discarding it.
# 응? 내 생각엔 아주 멋들어진 것 같은데
#
#  [!] Character '내' not found in the vocabulary. Discarding it.
# 응? 내 생각엔 아주 멋들어진 것 같은데
#
#  [!] Character '각' not found in the vocabulary. Discarding it.
# 응? 내 생각엔 아주 멋들어진 것 같은데
#
#  [!] Character '엔' not found in the vocabulary. Discarding it.
# 응? 내 생각엔 아주 멋들어진 것 같은데
#
#  [!] Character '주' not found in the vocabulary. Discarding it.
# 응? 내 생각엔 아주 멋들어진 것 같은데
#
#  [!] Character '멋' not found in the vocabulary. Discarding it.
# 응? 내 생각엔 아주 멋들어진 것 같은데
#
#  [!] Character '진' not found in the vocabulary. Discarding it.
# 아까부터 묻고 싶었던 건데, 뭘 준비한다는 거야?
#
#  [!] Character '까' not found in the vocabulary. Discarding it.
# 아까부터 묻고 싶었던 건데, 뭘 준비한다는 거야?
#
#  [!] Character '부' not found in the vocabulary. Discarding it.
# 아까부터 묻고 싶었던 건데, 뭘 준비한다는 거야?
#
#  [!] Character '터' not found in the vocabulary. Discarding it.
# 아까부터 묻고 싶었던 건데, 뭘 준비한다는 거야?
#
#  [!] Character '던' not found in the vocabulary. Discarding it.
# 아까부터 묻고 싶었던 건데, 뭘 준비한다는 거야?
#
#  [!] Character '뭘' not found in the vocabulary. Discarding it.
# 그래서 이 많은 실험을 한 거라니…
#
#  [!] Character '실' not found in the vocabulary. Discarding it.
# 그래서 이 많은 실험을 한 거라니…
#
#  [!] Character '험' not found in the vocabulary. Discarding it.
# 그래서 이 많은 실험을 한 거라니…
#
#  [!] Character '을' not found in the vocabulary. Discarding it.
# 수상한 게 딱 봐도 나쁜 사람 같거든!
#
#  [!] Character '쁜' not found in the vocabulary. Discarding it.
# 수상한 게 딱 봐도 나쁜 사람 같거든!
#
#  [!] Character '든' not found in the vocabulary. Discarding it.
# 그럼 역시 빌망을 찾으러 갈 수밖에 없겠네
#
#  [!] Character '빌' not found in the vocabulary. Discarding it.
# 그럼 역시 빌망을 찾으러 갈 수밖에 없겠네
#
#  [!] Character '찾' not found in the vocabulary. Discarding it.
# 그럼 역시 빌망을 찾으러 갈 수밖에 없겠네
#
#  [!] Character '러' not found in the vocabulary. Discarding it.
# 그럼 역시 빌망을 찾으러 갈 수밖에 없겠네
#
#  [!] Character '갈' not found in the vocabulary. Discarding it.
# 그럼 역시 빌망을 찾으러 갈 수밖에 없겠네
#
#  [!] Character '밖' not found in the vocabulary. Discarding it.
# 저 사람들을 따돌리고 얼른 두냐르자드를 쫓아가자!
#
#  [!] Character '람' not found in the vocabulary. Discarding it.
# 저 사람들을 따돌리고 얼른 두냐르자드를 쫓아가자!
#
#  [!] Character '따' not found in the vocabulary. Discarding it.
# 저 사람들을 따돌리고 얼른 두냐르자드를 쫓아가자!
#
#  [!] Character '얼' not found in the vocabulary. Discarding it.
# 저 사람들을 따돌리고 얼른 두냐르자드를 쫓아가자!
#
#  [!] Character '른' not found in the vocabulary. Discarding it.
# 저 사람들을 따돌리고 얼른 두냐르자드를 쫓아가자!
#
#  [!] Character '두' not found in the vocabulary. Discarding it.
# 저 사람들을 따돌리고 얼른 두냐르자드를 쫓아가자!
#
#  [!] Character '드' not found in the vocabulary. Discarding it.
# 저 사람들을 따돌리고 얼른 두냐르자드를 쫓아가자!
#
#  [!] Character '를' not found in the vocabulary. Discarding it.
# 저 사람들을 따돌리고 얼른 두냐르자드를 쫓아가자!
#
#  [!] Character '쫓' not found in the vocabulary. Discarding it.
# #그중에는 반드시 {M#여동생}{F#오빠}의 소식이 있을 거야!
#
#  [!] Character '중' not found in the vocabulary. Discarding it.
# #그중에는 반드시 {M#여동생}{F#오빠}의 소식이 있을 거야!
#
#  [!] Character '반' not found in the vocabulary. Discarding it.
# #그중에는 반드시 {M#여동생}{F#오빠}의 소식이 있을 거야!
#
#  [!] Character '드' not found in the vocabulary. Discarding it.
# #그중에는 반드시 {M#여동생}{F#오빠}의 소식이 있을 거야!
#
#  [!] Character '{' not found in the vocabulary. Discarding it.
# #그중에는 반드시 {M#여동생}{F#오빠}의 소식이 있을 거야!
#
#  [!] Character '동' not found in the vocabulary. Discarding it.
# #그중에는 반드시 {M#여동생}{F#오빠}의 소식이 있을 거야!
#
#  [!] Character '생' not found in the vocabulary. Discarding it.
# #그중에는 반드시 {M#여동생}{F#오빠}의 소식이 있을 거야!
#
#  [!] Character '}' not found in the vocabulary. Discarding it.
# #그중에는 반드시 {M#여동생}{F#오빠}의 소식이 있을 거야!
#
#  [!] Character '빠' not found in the vocabulary. Discarding it.
# #그중에는 반드시 {M#여동생}{F#오빠}의 소식이 있을 거야!
#
#  [!] Character '소' not found in the vocabulary. Discarding it.
# #그중에는 반드시 {M#여동생}{F#오빠}의 소식이 있을 거야!
#
#  [!] Character '식' not found in the vocabulary. Discarding it.
# 눈빛을 보니까 정말 억울한 모양인데
#
#  [!] Character '빛' not found in the vocabulary. Discarding it.
# 눈빛을 보니까 정말 억울한 모양인데
#
#  [!] Character '억' not found in the vocabulary. Discarding it.
# 눈빛을 보니까 정말 억울한 모양인데
#
#  [!] Character '모' not found in the vocabulary. Discarding it.
# 눈빛을 보니까 정말 억울한 모양인데
#
#  [!] Character '양' not found in the vocabulary. Discarding it.
# 너, 너는… 아니, 너희는 누구야…?
#
#  [!] Character '희' not found in the vocabulary. Discarding it.
# 너, 너는… 아니, 너희는 누구야…?
#
#  [!] Character '누' not found in the vocabulary. Discarding it.
# 제발 이루어져라…
#
#  [!] Character '루' not found in the vocabulary. Discarding it.
# 제발 이루어져라…
#
#  [!] Character '져' not found in the vocabulary. Discarding it.
# 그나저나 어떻게 상품을 확인할 생각을 한 거야?
#
#  [!] Character '품' not found in the vocabulary. Discarding it.
# 그나저나 어떻게 상품을 확인할 생각을 한 거야?
#
#  [!] Character '확' not found in the vocabulary. Discarding it.
# 으아! 우, 우리도 나름의 사정이 있다고!
#
#  [!] Character '름' not found in the vocabulary. Discarding it.
# 으아! 우, 우리도 나름의 사정이 있다고!
#
#  [!] Character '의' not found in the vocabulary. Discarding it.
# 으아! 우, 우리도 나름의 사정이 있다고!
#
#  [!] Character '있' not found in the vocabulary. Discarding it.
# 결국 너도 「다크 히어로」가 누군지 모르는 거잖아
#
#  [!] Character '크' not found in the vocabulary. Discarding it.
# 결국 너도 「다크 히어로」가 누군지 모르는 거잖아
#
#  [!] Character '히' not found in the vocabulary. Discarding it.
# 결국 너도 「다크 히어로」가 누군지 모르는 거잖아
#
#  [!] Character '군' not found in the vocabulary. Discarding it.
# 갑자기 진지하게 군다고 용서해 줄 거 같아?
#
#  [!] Character '갑' not found in the vocabulary. Discarding it.
# 갑자기 진지하게 군다고 용서해 줄 거 같아?
#
#  [!] Character '진' not found in the vocabulary. Discarding it.
# 갑자기 진지하게 군다고 용서해 줄 거 같아?
#
#  [!] Character '군' not found in the vocabulary. Discarding it.
# 어… 응? 우리를 초대하는 거였어?
#
#  [!] Character '초' not found in the vocabulary. Discarding it.
# 어… 응? 우리를 초대하는 거였어?
#
#  [!] Character '대' not found in the vocabulary. Discarding it.
# 왜… 왜 제자리로 돌아왔지?
#
#  [!] Character '왜' not found in the vocabulary. Discarding it.
# 왜… 왜 제자리로 돌아왔지?
#
#  [!] Character '왔' not found in the vocabulary. Discarding it.
# 예쁘다. 게다가 힘이 넘치는 것 같아
#
#  [!] Character '쁘' not found in the vocabulary. Discarding it.
# 윽, 뒤에 무슨 말을 할지 너무 뻔해——
#
#  [!] Character '윽' not found in the vocabulary. Discarding it.
# 윽, 뒤에 무슨 말을 할지 너무 뻔해——
#
#  [!] Character '뒤' not found in the vocabulary. Discarding it.
# 윽, 뒤에 무슨 말을 할지 너무 뻔해——
#
#  [!] Character '뻔' not found in the vocabulary. Discarding it.
# 윽, 뒤에 무슨 말을 할지 너무 뻔해——
#
#  [!] Character '해' not found in the vocabulary. Discarding it.
# 윽, 뒤에 무슨 말을 할지 너무 뻔해——
#
#  [!] Character '—' not found in the vocabulary. Discarding it.
# 설마 방금 몰래 타르탈리아를 따라간 건가?
#
#  [!] Character '설' not found in the vocabulary. Discarding it.
# 설마 방금 몰래 타르탈리아를 따라간 건가?
#
#  [!] Character '방' not found in the vocabulary. Discarding it.
# 설마 방금 몰래 타르탈리아를 따라간 건가?
#
#  [!] Character '몰' not found in the vocabulary. Discarding it.
# 설마 방금 몰래 타르탈리아를 따라간 건가?
#
#  [!] Character '래' not found in the vocabulary. Discarding it.
# 설마 방금 몰래 타르탈리아를 따라간 건가?
#
#  [!] Character '타' not found in the vocabulary. Discarding it.
# 설마 방금 몰래 타르탈리아를 따라간 건가?
#
#  [!] Character '탈' not found in the vocabulary. Discarding it.
# 설마 방금 몰래 타르탈리아를 따라간 건가?
#
#  [!] Character '따' not found in the vocabulary. Discarding it.
# 그럼 계획을 짜야 하는 거 아니야? 시는 전혀 상관없잖아…
#
#  [!] Character '획' not found in the vocabulary. Discarding it.
# 그럼 계획을 짜야 하는 거 아니야? 시는 전혀 상관없잖아…
#
#  [!] Character '짜' not found in the vocabulary. Discarding it.
# 그럼 계획을 짜야 하는 거 아니야? 시는 전혀 상관없잖아…
#
#  [!] Character '혀' not found in the vocabulary. Discarding it.
# 설마… 네가 「불씨」가 될 생각이야?
#
#  [!] Character '설' not found in the vocabulary. Discarding it.
# 설마… 네가 「불씨」가 될 생각이야?
#
#  [!] Character '불' not found in the vocabulary. Discarding it.
# 설마… 네가 「불씨」가 될 생각이야?
#
#  [!] Character '씨' not found in the vocabulary. Discarding it.
# 설마… 네가 「불씨」가 될 생각이야?
#
#  [!] Character '될' not found in the vocabulary. Discarding it.

# %%
# !CUDA_VISIBLE_DEVICES="0" python3 /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/train_gpt_xtts.py
#    --restore_path  /home/pengejeen/.local/share/tts/tts_models--multilingual--multi-dataset--xtts_v2/model.pth \
# Out:
# >> DVAE weights restored from: /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/XTTS_v2.0_original_model_files/dvae.pth
#  | > Found 386 files in /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/datasets
#  > Training Environment:
#  | > Backend: Torch
#  | > Mixed precision: False
#  | > Precision: float32
#  | > Current device: 0
#  | > Num. of GPUs: 1
#  | > Num. of CPUs: 12
#  | > Num. of Torch Threads: 1
#  | > Torch seed: 1
#  | > Torch CUDNN: True
#  | > Torch CUDNN deterministic: False
#  | > Torch CUDNN benchmark: False
#  | > Torch TF32 MatMul: False
#  > Start Tensorboard: tensorboard --logdir=/home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > Model has 518442047 parameters
#
#  > EPOCH: 0/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#  > Filtering invalid eval samples!!
#  > Total eval samples after filtering: 3
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.3806436061859131 (+0)
#      | > avg_loss_text_ce: 0.0338304303586483 (+0)
#      | > avg_loss_mel_ce: 3.4577364921569824 (+0)
#      | > avg_loss: 3.4915668964385986 (+0)
#
#
#  > EPOCH: 1/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#  > Sampling by language: dict_keys(['ko'])
#
#  > TRAINING (2024-05-24 02:37:30)
#
#    --> TIME: 2024-05-24 02:37:31 -- STEP: 0/128 -- GLOBAL_STEP: 0
#      | > loss_text_ce: 0.03583338484168053  (0.03583338484168053)
#      | > loss_mel_ce: 3.916569471359253  (3.916569471359253)
#      | > loss: 0.04705241695046425  (0.04705241695046425)
#      | > current_lr: 5e-06
#      | > step_time: 0.3309  (0.33086705207824707)
#      | > loader_time: 0.4639  (0.46389007568359375)
#
#
#    --> TIME: 2024-05-24 02:39:46 -- STEP: 50/128 -- GLOBAL_STEP: 50
#      | > loss_text_ce: 0.035603947937488556  (0.03536011032760143)
#      | > loss_mel_ce: 3.8167121410369873  (3.652122769355774)
#      | > loss: 0.045860908925533295  (0.04389860637485981)
#      | > current_lr: 5e-06
#      | > step_time: 1.4741  (2.325994729995728)
#      | > loader_time: 0.0118  (0.010999994277954101)
#
#
#    --> TIME: 2024-05-24 02:42:16 -- STEP: 100/128 -- GLOBAL_STEP: 100
#      | > loss_text_ce: 0.03463628143072128  (0.03533158518373966)
#      | > loss_mel_ce: 3.775564670562744  (3.6299622750282285)
#      | > loss: 0.0453595370054245  (0.04363445162773133)
#      | > current_lr: 5e-06
#      | > step_time: 2.5268  (2.382272541522978)
#      | > loader_time: 0.0196  (0.011048574447631836)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.016521215438842773 (-0.3641223907470703)
#      | > avg_loss_text_ce: 0.033782634884119034 (-4.779547452926636e-05)
#      | > avg_loss_mel_ce: 3.235058069229126 (-0.22267842292785645)
#      | > avg_loss: 3.268840789794922 (-0.22272610664367676)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_128.pth
#
#  > EPOCH: 2/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 02:44:24)
#
#    --> TIME: 2024-05-24 02:46:05 -- STEP: 22/128 -- GLOBAL_STEP: 150
#      | > loss_text_ce: 0.03855572268366814  (0.03527121550657533)
#      | > loss_mel_ce: 4.615252494812012  (3.5305109565908257)
#      | > loss: 0.0554024800658226  (0.04244978878308426)
#      | > current_lr: 5e-06
#      | > step_time: 1.9598  (2.881570079109886)
#      | > loader_time: 0.0071  (0.012117505073547363)
#
#
#    --> TIME: 2024-05-24 02:49:44 -- STEP: 72/128 -- GLOBAL_STEP: 200
#      | > loss_text_ce: 0.038420550525188446  (0.035144951220394835)
#      | > loss_mel_ce: 3.6619932651519775  (3.484480473730299)
#      | > loss: 0.044052544981241226  (0.04190030357696944)
#      | > current_lr: 5e-06
#      | > step_time: 1.714  (2.8772852222124734)
#      | > loader_time: 0.0258  (0.012574272023306953)
#
#
#    --> TIME: 2024-05-24 02:55:18 -- STEP: 122/128 -- GLOBAL_STEP: 250
#      | > loss_text_ce: 0.03484344109892845  (0.03467896153203777)
#      | > loss_mel_ce: 3.0257821083068848  (3.4506354273342694)
#      | > loss: 0.036436017602682114  (0.04149183881331664)
#      | > current_lr: 5e-06
#      | > step_time: 4.6612  (3.493642502143735)
#      | > loader_time: 0.0196  (0.01177195056540067)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.03092169761657715 (+0.014400482177734375)
#      | > avg_loss_text_ce: 0.03372599184513092 (-5.66430389881134e-05)
#      | > avg_loss_mel_ce: 3.099311351776123 (-0.13574671745300293)
#      | > avg_loss: 3.1330373287200928 (-0.1358034610748291)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_256.pth
#
#  > EPOCH: 3/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 02:56:04)
#
#    --> TIME: 2024-05-24 02:59:33 -- STEP: 44/128 -- GLOBAL_STEP: 300
#      | > loss_text_ce: 0.031133608892560005  (0.03572185832837766)
#      | > loss_mel_ce: 3.4880547523498535  (3.3858178474686365)
#      | > loss: 0.041895098984241486  (0.04073261630467393)
#      | > current_lr: 5e-06
#      | > step_time: 3.7032  (3.3633338050408796)
#      | > loader_time: 0.007  (0.010908961296081543)
#
#
#    --> TIME: 2024-05-24 03:03:34 -- STEP: 94/128 -- GLOBAL_STEP: 350
#      | > loss_text_ce: 0.033154964447021484  (0.03496794325319378)
#      | > loss_mel_ce: 3.0158193111419678  (3.3245701840583313)
#      | > loss: 0.03629731386899948  (0.039994502400464205)
#      | > current_lr: 5e-06
#      | > step_time: 3.8993  (3.340059090167918)
#      | > loader_time: 0.0053  (0.010125540672464574)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.03029608726501465 (-0.0006256103515625)
#      | > avg_loss_text_ce: 0.03363450616598129 (-9.148567914962769e-05)
#      | > avg_loss_mel_ce: 3.0401298999786377 (-0.05918145179748535)
#      | > avg_loss: 3.0737643241882324 (-0.05927300453186035)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_384.pth
#
#  > EPOCH: 4/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 03:06:33)
#
#    --> TIME: 2024-05-24 03:07:37 -- STEP: 16/128 -- GLOBAL_STEP: 400
#      | > loss_text_ce: 0.028988732025027275  (0.03494140680413693)
#      | > loss_mel_ce: 3.240669012069702  (3.237126499414444)
#      | > loss: 0.03892450034618378  (0.03895318997092545)
#      | > current_lr: 5e-06
#      | > step_time: 2.0118  (2.6836098581552505)
#      | > loader_time: 0.0043  (0.04295271635055542)
#
#
#    --> TIME: 2024-05-24 03:11:32 -- STEP: 66/128 -- GLOBAL_STEP: 450
#      | > loss_text_ce: 0.031078176572918892  (0.03384093996701819)
#      | > loss_mel_ce: 3.1258344650268555  (3.2392762791026724)
#      | > loss: 0.03758229315280914  (0.03896568190645089)
#      | > current_lr: 5e-06
#      | > step_time: 3.5331  (3.1195191397811426)
#      | > loader_time: 0.005  (0.01506369764154609)
#
#
#    --> TIME: 2024-05-24 03:15:18 -- STEP: 116/128 -- GLOBAL_STEP: 500
#      | > loss_text_ce: 0.03188330680131912  (0.03383549994885406)
#      | > loss_mel_ce: 3.2764408588409424  (3.2241567085529197)
#      | > loss: 0.039384812116622925  (0.038785622358835974)
#      | > current_lr: 5e-06
#      | > step_time: 3.5607  (3.1109821570330647)
#      | > loader_time: 0.0049  (0.011034529784630093)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.024535417556762695 (-0.005760669708251953)
#      | > avg_loss_text_ce: 0.033539507538080215 (-9.499862790107727e-05)
#      | > avg_loss_mel_ce: 3.0030384063720703 (-0.03709149360656738)
#      | > avg_loss: 3.0365779399871826 (-0.037186384201049805)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_512.pth
#
#  > EPOCH: 5/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 03:16:32)
#
#    --> TIME: 2024-05-24 03:19:30 -- STEP: 38/128 -- GLOBAL_STEP: 550
#      | > loss_text_ce: 0.033393580466508865  (0.03414826732324925)
#      | > loss_mel_ce: 2.974248170852661  (3.154043335663645)
#      | > loss: 0.03580525889992714  (0.03795466258337623)
#      | > current_lr: 5e-06
#      | > step_time: 5.9723  (2.8788393422176966)
#      | > loader_time: 0.0055  (0.00730028277949283)
#
#
#    --> TIME: 2024-05-24 03:23:16 -- STEP: 88/128 -- GLOBAL_STEP: 600
#      | > loss_text_ce: 0.0297755878418684  (0.033561882054941206)
#      | > loss_mel_ce: 2.9644811153411865  (3.1874151663346733)
#      | > loss: 0.03564591333270073  (0.03834496544335376)
#      | > current_lr: 5e-06
#      | > step_time: 2.1191  (2.8365826606750484)
#      | > loader_time: 0.0051  (0.006874287670308893)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.024474382400512695 (-6.103515625e-05)
#      | > avg_loss_text_ce: 0.03342650085687637 (-0.00011300668120384216)
#      | > avg_loss_mel_ce: 2.9720535278320312 (-0.030984878540039062)
#      | > avg_loss: 3.0054800510406494 (-0.031097888946533203)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_640.pth
#
#  > EPOCH: 6/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 03:26:18)
#
#    --> TIME: 2024-05-24 03:27:03 -- STEP: 10/128 -- GLOBAL_STEP: 650
#      | > loss_text_ce: 0.02918308414518833  (0.03254458960145712)
#      | > loss_mel_ce: 3.1063528060913086  (3.1873183727264403)
#      | > loss: 0.03732781112194061  (0.038331703096628186)
#      | > current_lr: 5e-06
#      | > step_time: 4.2228  (3.259449672698975)
#      | > loader_time: 0.0049  (0.005966353416442871)
#
#
#    --> TIME: 2024-05-24 03:30:58 -- STEP: 60/128 -- GLOBAL_STEP: 700
#      | > loss_text_ce: 0.03694145008921623  (0.033196803927421546)
#      | > loss_mel_ce: 3.2285256385803223  (3.152346150080363)
#      | > loss: 0.038874611258506775  (0.03792313126226266)
#      | > current_lr: 5e-06
#      | > step_time: 3.8857  (3.4826484958330792)
#      | > loader_time: 0.0052  (0.006189092000325521)
#
#
#    --> TIME: 2024-05-24 03:34:58 -- STEP: 110/128 -- GLOBAL_STEP: 750
#      | > loss_text_ce: 0.03281962499022484  (0.03339477139101789)
#      | > loss_mel_ce: 3.1006052494049072  (3.121832286227833)
#      | > loss: 0.03730267658829689  (0.03756222758780823)
#      | > current_lr: 5e-06
#      | > step_time: 3.824  (3.4418582786213268)
#      | > loader_time: 0.0052  (0.006104460629549893)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.016542434692382812 (-0.007931947708129883)
#      | > avg_loss_text_ce: 0.03329192474484444 (-0.00013457611203193665)
#      | > avg_loss_mel_ce: 2.944258213043213 (-0.02779531478881836)
#      | > avg_loss: 2.9775500297546387 (-0.027930021286010742)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_768.pth
#
#  > EPOCH: 7/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 03:36:46)
#
#    --> TIME: 2024-05-24 03:38:55 -- STEP: 32/128 -- GLOBAL_STEP: 800
#      | > loss_text_ce: 0.03638431057333946  (0.03269085276406258)
#      | > loss_mel_ce: 3.119004011154175  (3.0587583258748055)
#      | > loss: 0.037564147263765335  (0.03680296731181443)
#      | > current_lr: 5e-06
#      | > step_time: 3.7772  (2.6142064705491066)
#      | > loader_time: 0.0055  (0.0061288923025131226)
#
#
#    --> TIME: 2024-05-24 03:42:21 -- STEP: 82/128 -- GLOBAL_STEP: 850
#      | > loss_text_ce: 0.030674586072564125  (0.03330722051422771)
#      | > loss_mel_ce: 3.2019877433776855  (3.127202316028316)
#      | > loss: 0.03848407790064812  (0.03762511459247368)
#      | > current_lr: 5e-06
#      | > step_time: 1.5205  (2.701205698455252)
#      | > loader_time: 0.005  (0.005645958388723979)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.021483659744262695 (+0.004941225051879883)
#      | > avg_loss_text_ce: 0.033157818019390106 (-0.00013410672545433044)
#      | > avg_loss_mel_ce: 2.9159483909606934 (-0.02830982208251953)
#      | > avg_loss: 2.949106216430664 (-0.02844381332397461)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_896.pth
#
#  > EPOCH: 8/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 03:45:42)
#
#    --> TIME: 2024-05-24 03:45:57 -- STEP: 4/128 -- GLOBAL_STEP: 900
#      | > loss_text_ce: 0.03086467646062374  (0.0380273605696857)
#      | > loss_mel_ce: 2.9694442749023438  (3.1162763237953186)
#      | > loss: 0.03571796417236328  (0.037551235407590866)
#      | > current_lr: 5e-06
#      | > step_time: 1.8032  (2.38653028011322)
#      | > loader_time: 0.0042  (0.004854738712310791)
#
#
#    --> TIME: 2024-05-24 03:49:45 -- STEP: 54/128 -- GLOBAL_STEP: 950
#      | > loss_text_ce: 0.030311664566397667  (0.03326116981743664)
#      | > loss_mel_ce: 2.8254945278167725  (3.0737901793585882)
#      | > loss: 0.03399769216775894  (0.0369887071903105)
#      | > current_lr: 5e-06
#      | > step_time: 5.2517  (3.2007540376098067)
#      | > loader_time: 0.0051  (0.006075978279113769)
#
#
#    --> TIME: 2024-05-24 03:53:52 -- STEP: 104/128 -- GLOBAL_STEP: 1000
#      | > loss_text_ce: 0.03601732477545738  (0.03300410999844854)
#      | > loss_mel_ce: 3.2097389698028564  (3.069554092792364)
#      | > loss: 0.03863995894789696  (0.03693521742780621)
#      | > current_lr: 5e-06
#      | > step_time: 3.3854  (3.2332554367872386)
#      | > loader_time: 0.0054  (0.005803252641971295)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.015079975128173828 (-0.006403684616088867)
#      | > avg_loss_text_ce: 0.03299880772829056 (-0.00015901029109954834)
#      | > avg_loss_mel_ce: 2.8939266204833984 (-0.022021770477294922)
#      | > avg_loss: 2.9269254207611084 (-0.022180795669555664)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_1024.pth
#
#  > EPOCH: 9/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 03:56:07)
#
#    --> TIME: 2024-05-24 03:57:52 -- STEP: 26/128 -- GLOBAL_STEP: 1050
#      | > loss_text_ce: 0.03484850004315376  (0.03383115571565353)
#      | > loss_mel_ce: 3.133042573928833  (3.1429053911795983)
#      | > loss: 0.03771298751235008  (0.037818293302105024)
#      | > current_lr: 5e-06
#      | > step_time: 3.5511  (2.5382537566698513)
#      | > loader_time: 0.0058  (0.0061412224402794474)
#
#
#    --> TIME: 2024-05-24 04:01:38 -- STEP: 76/128 -- GLOBAL_STEP: 1100
#      | > loss_text_ce: 0.025351285934448242  (0.03386968366899773)
#      | > loss_mel_ce: 2.858895778656006  (3.101585137216668)
#      | > loss: 0.03433627635240555  (0.03732684396795536)
#      | > current_lr: 5e-06
#      | > step_time: 3.667  (2.839101220432081)
#      | > loader_time: 0.0051  (0.005706432618592915)
#
#
#    --> TIME: 2024-05-24 04:04:41 -- STEP: 126/128 -- GLOBAL_STEP: 1150
#      | > loss_text_ce: 0.042728617787361145  (0.03383007781609656)
#      | > loss_mel_ce: 3.0100669860839844  (3.086150701083834)
#      | > loss: 0.0363428071141243  (0.03714262915863877)
#      | > current_lr: 5e-06
#      | > step_time: 2.1069  (2.7336008056761716)
#      | > loader_time: 0.0048  (0.0056003861957126195)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02605891227722168 (+0.010978937149047852)
#      | > avg_loss_text_ce: 0.03284731134772301 (-0.00015149638056755066)
#      | > avg_loss_mel_ce: 2.8744943141937256 (-0.01943230628967285)
#      | > avg_loss: 2.907341718673706 (-0.019583702087402344)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_1152.pth
#
#  > EPOCH: 10/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 04:05:03)
#
#    --> TIME: 2024-05-24 04:08:37 -- STEP: 48/128 -- GLOBAL_STEP: 1200
#      | > loss_text_ce: 0.03312297910451889  (0.03342862819166234)
#      | > loss_mel_ce: 3.2033984661102295  (2.9681548078854867)
#      | > loss: 0.03853001818060875  (0.03573313696930805)
#      | > current_lr: 5e-06
#      | > step_time: 3.3508  (3.1894586086273193)
#      | > loader_time: 0.0051  (0.006284922361373901)
#
#
#    --> TIME: 2024-05-24 04:12:35 -- STEP: 98/128 -- GLOBAL_STEP: 1250
#      | > loss_text_ce: 0.03192289173603058  (0.03392430469013599)
#      | > loss_mel_ce: 2.971386671066284  (2.977251970038122)
#      | > loss: 0.03575368598103523  (0.035847337498348585)
#      | > current_lr: 5e-06
#      | > step_time: 2.475  (3.227935778851412)
#      | > loader_time: 0.0056  (0.006103325863273778)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.01585865020751953 (-0.010200262069702148)
#      | > avg_loss_text_ce: 0.032715074717998505 (-0.00013223662972450256)
#      | > avg_loss_mel_ce: 2.856783151626587 (-0.017711162567138672)
#      | > avg_loss: 2.889498233795166 (-0.01784348487854004)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_1280.pth
#
#  > EPOCH: 11/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 04:15:16)
#
#    --> TIME: 2024-05-24 04:16:46 -- STEP: 20/128 -- GLOBAL_STEP: 1300
#      | > loss_text_ce: 0.02981089986860752  (0.03167008003219962)
#      | > loss_mel_ce: 3.0657598972320557  (2.890231728553772)
#      | > loss: 0.03685203567147255  (0.03478454621508718)
#      | > current_lr: 5e-06
#      | > step_time: 3.0057  (2.738755536079407)
#      | > loader_time: 0.0054  (0.005713987350463867)
#
#
#    --> TIME: 2024-05-24 04:20:05 -- STEP: 70/128 -- GLOBAL_STEP: 1350
#      | > loss_text_ce: 0.03275071457028389  (0.03257619703986815)
#      | > loss_mel_ce: 2.7967872619628906  (2.9580698115485053)
#      | > loss: 0.033684976398944855  (0.03560292941651174)
#      | > current_lr: 5e-06
#      | > step_time: 3.5823  (2.6071705034800936)
#      | > loader_time: 0.0055  (0.006042289733886719)
#
#
#    --> TIME: 2024-05-24 04:23:40 -- STEP: 120/128 -- GLOBAL_STEP: 1400
#      | > loss_text_ce: 0.0356471911072731  (0.032953846314921986)
#      | > loss_mel_ce: 3.0323069095611572  (2.9848693986733754)
#      | > loss: 0.03652326390147209  (0.03592646787874402)
#      | > current_lr: 5e-06
#      | > step_time: 1.4227  (2.7229855835437773)
#      | > loader_time: 0.005  (0.005779542525609334)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.019936800003051758 (+0.0040781497955322266)
#      | > avg_loss_text_ce: 0.03258470445871353 (-0.00013037025928497314)
#      | > avg_loss_mel_ce: 2.841190814971924 (-0.015592336654663086)
#      | > avg_loss: 2.8737754821777344 (-0.01572275161743164)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_1408.pth
#
#  > EPOCH: 12/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 04:24:25)
#
#    --> TIME: 2024-05-24 04:27:21 -- STEP: 42/128 -- GLOBAL_STEP: 1450
#      | > loss_text_ce: 0.031103715300559998  (0.034478288631708855)
#      | > loss_mel_ce: 3.0658812522888184  (2.98451756863367)
#      | > loss: 0.036868866533041  (0.03594042755486001)
#      | > current_lr: 5e-06
#      | > step_time: 1.7816  (2.630308088802156)
#      | > loader_time: 0.0053  (0.007164478302001953)
#
#
#    --> TIME: 2024-05-24 04:30:51 -- STEP: 92/128 -- GLOBAL_STEP: 1500
#      | > loss_text_ce: 0.028931833803653717  (0.033396330540594835)
#      | > loss_mel_ce: 3.40421986579895  (2.999743741491565)
#      | > loss: 0.04087085276842117  (0.036108810940514456)
#      | > current_lr: 5e-06
#      | > step_time: 2.0857  (2.702744380287502)
#      | > loader_time: 0.0064  (0.00653625312058822)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02198004722595215 (+0.0020432472229003906)
#      | > avg_loss_text_ce: 0.032455556094646454 (-0.00012914836406707764)
#      | > avg_loss_mel_ce: 2.827866792678833 (-0.01332402229309082)
#      | > avg_loss: 2.8603222370147705 (-0.013453245162963867)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_1536.pth
#
#  > EPOCH: 13/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 04:33:48)
#
#    --> TIME: 2024-05-24 04:34:51 -- STEP: 14/128 -- GLOBAL_STEP: 1550
#      | > loss_text_ce: 0.035838447511196136  (0.03295808418520859)
#      | > loss_mel_ce: 2.8477864265441895  (2.811090213911874)
#      | > loss: 0.03432886675000191  (0.033857718110084534)
#      | > current_lr: 5e-06
#      | > step_time: 2.3142  (3.2464771270751953)
#      | > loader_time: 0.0052  (0.005586300577436175)
#
#
#    --> TIME: 2024-05-24 04:38:45 -- STEP: 64/128 -- GLOBAL_STEP: 1600
#      | > loss_text_ce: 0.03357149660587311  (0.033259467949392274)
#      | > loss_mel_ce: 2.9230763912200928  (2.9460244812071323)
#      | > loss: 0.035198189318180084  (0.03546766663203016)
#      | > current_lr: 5e-06
#      | > step_time: 1.8668  (3.3268876671791077)
#      | > loader_time: 0.0056  (0.0059356018900871286)
#
#
#    --> TIME: 2024-05-24 04:42:50 -- STEP: 114/128 -- GLOBAL_STEP: 1650
#      | > loss_text_ce: 0.02883271314203739  (0.033062367422277444)
#      | > loss_mel_ce: 3.2192282676696777  (2.936972787505702)
#      | > loss: 0.03866739198565483  (0.035357561975456135)
#      | > current_lr: 5e-06
#      | > step_time: 2.4745  (3.2265032697142217)
#      | > loader_time: 0.0053  (0.005968018581992702)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.028205156326293945 (+0.006225109100341797)
#      | > avg_loss_text_ce: 0.03231162577867508 (-0.0001439303159713745)
#      | > avg_loss_mel_ce: 2.8151886463165283 (-0.012678146362304688)
#      | > avg_loss: 2.8475003242492676 (-0.01282191276550293)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_1664.pth
#
#  > EPOCH: 14/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 04:44:11)
#
#    --> TIME: 2024-05-24 04:47:12 -- STEP: 36/128 -- GLOBAL_STEP: 1700
#      | > loss_text_ce: 0.025162922218441963  (0.032680989863971874)
#      | > loss_mel_ce: 2.6345131397247314  (2.957231488492754)
#      | > loss: 0.03166281059384346  (0.03559419719709291)
#      | > current_lr: 5e-06
#      | > step_time: 2.839  (3.4403519696659512)
#      | > loader_time: 0.0058  (0.005932397312588162)
#
#
#    --> TIME: 2024-05-24 04:50:52 -- STEP: 86/128 -- GLOBAL_STEP: 1750
#      | > loss_text_ce: 0.030255556106567383  (0.03238043295176224)
#      | > loss_mel_ce: 2.9978954792022705  (2.9512059993522115)
#      | > loss: 0.03604941815137863  (0.03551888691131459)
#      | > current_lr: 5e-06
#      | > step_time: 3.5106  (3.1740829112917877)
#      | > loader_time: 0.0058  (0.006012040515278658)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.018012285232543945 (-0.01019287109375)
#      | > avg_loss_text_ce: 0.03215516358613968 (-0.0001564621925354004)
#      | > avg_loss_mel_ce: 2.8018686771392822 (-0.013319969177246094)
#      | > avg_loss: 2.834023952484131 (-0.013476371765136719)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_1792.pth
#
#  > EPOCH: 15/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 04:53:26)
#
#    --> TIME: 2024-05-24 04:54:02 -- STEP: 8/128 -- GLOBAL_STEP: 1800
#      | > loss_text_ce: 0.031178230419754982  (0.03201171616092324)
#      | > loss_mel_ce: 2.6575684547424316  (2.852226734161377)
#      | > loss: 0.03200889006257057  (0.034336171578615904)
#      | > current_lr: 5e-06
#      | > step_time: 4.6282  (2.5805090069770813)
#      | > loader_time: 0.0086  (0.006034731864929199)
#
#
#    --> TIME: 2024-05-24 04:57:25 -- STEP: 58/128 -- GLOBAL_STEP: 1850
#      | > loss_text_ce: 0.027909282594919205  (0.03207057711250825)
#      | > loss_mel_ce: 2.9211549758911133  (2.9401185759182633)
#      | > loss: 0.03510790690779686  (0.03538320470472862)
#      | > current_lr: 5e-06
#      | > step_time: 2.583  (2.556090132943515)
#      | > loader_time: 0.0057  (0.005771653405551253)
#
#
#    --> TIME: 2024-05-24 05:00:40 -- STEP: 108/128 -- GLOBAL_STEP: 1900
#      | > loss_text_ce: 0.02838459610939026  (0.0322309299717071)
#      | > loss_mel_ce: 2.9482200145721436  (2.9175400932629905)
#      | > loss: 0.03543576970696449  (0.03511632213162051)
#      | > current_lr: 5e-06
#      | > step_time: 4.1643  (2.5262192774701995)
#      | > loader_time: 0.0058  (0.00588587478355125)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.016125202178955078 (-0.0018870830535888672)
#      | > avg_loss_text_ce: 0.03199366480112076 (-0.0001614987850189209)
#      | > avg_loss_mel_ce: 2.789151191711426 (-0.012717485427856445)
#      | > avg_loss: 2.8211448192596436 (-0.012879133224487305)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_1920.pth
#
#  > EPOCH: 16/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 05:02:04)
#
#    --> TIME: 2024-05-24 05:04:17 -- STEP: 30/128 -- GLOBAL_STEP: 1950
#      | > loss_text_ce: 0.030569376423954964  (0.03275773978481691)
#      | > loss_mel_ce: 3.102309226989746  (2.980358123779297)
#      | > loss: 0.037296172231435776  (0.03587042763829231)
#      | > current_lr: 5e-06
#      | > step_time: 3.3778  (3.0819028854370116)
#      | > loader_time: 0.0077  (0.006520597139994303)
#
#
#    --> TIME: 2024-05-24 05:08:10 -- STEP: 80/128 -- GLOBAL_STEP: 2000
#      | > loss_text_ce: 0.03135371953248978  (0.03225256835576147)
#      | > loss_mel_ce: 2.917682647705078  (2.9353035151958466)
#      | > loss: 0.0351075753569603  (0.03532804907299579)
#      | > current_lr: 5e-06
#      | > step_time: 2.7029  (3.205368998646736)
#      | > loader_time: 0.0054  (0.0060617029666900635)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.020845651626586914 (+0.004720449447631836)
#      | > avg_loss_text_ce: 0.03183377534151077 (-0.00015988945960998535)
#      | > avg_loss_mel_ce: 2.7767679691314697 (-0.012383222579956055)
#      | > avg_loss: 2.8086018562316895 (-0.012542963027954102)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_2048.pth
#
#  > EPOCH: 17/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 05:11:50)
#
#    --> TIME: 2024-05-24 05:12:03 -- STEP: 2/128 -- GLOBAL_STEP: 2050
#      | > loss_text_ce: 0.03149595484137535  (0.031382620334625244)
#      | > loss_mel_ce: 3.3053882122039795  (2.8583004474639893)
#      | > loss: 0.03972481191158295  (0.034400989301502705)
#      | > current_lr: 5e-06
#      | > step_time: 3.5356  (3.590634822845459)
#      | > loader_time: 0.0058  (0.005840182304382324)
#
#
#    --> TIME: 2024-05-24 05:15:58 -- STEP: 52/128 -- GLOBAL_STEP: 2100
#      | > loss_text_ce: 0.028984693810343742  (0.03225896711676167)
#      | > loss_mel_ce: 2.7253024578094482  (2.8566886507547817)
#      | > loss: 0.03278913348913193  (0.03439223426035963)
#      | > current_lr: 5e-06
#      | > step_time: 1.6203  (3.1387720153881955)
#      | > loader_time: 0.0052  (0.005760362515082728)
#
#
#    --> TIME: 2024-05-24 05:19:55 -- STEP: 102/128 -- GLOBAL_STEP: 2150
#      | > loss_text_ce: 0.04724888876080513  (0.03240730956781146)
#      | > loss_mel_ce: 2.729339122772217  (2.857906077422348)
#      | > loss: 0.033054620027542114  (0.03440849338749461)
#      | > current_lr: 5e-06
#      | > step_time: 0.8864  (3.1756320700925937)
#      | > loader_time: 0.0063  (0.006022619266136022)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.01884007453918457 (-0.0020055770874023438)
#      | > avg_loss_text_ce: 0.03167504817247391 (-0.00015872716903686523)
#      | > avg_loss_mel_ce: 2.7644925117492676 (-0.012275457382202148)
#      | > avg_loss: 2.7961676120758057 (-0.012434244155883789)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_2176.pth
#
#  > EPOCH: 18/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 05:21:47)
#
#    --> TIME: 2024-05-24 05:23:36 -- STEP: 24/128 -- GLOBAL_STEP: 2200
#      | > loss_text_ce: 0.03231929615139961  (0.03298046416603029)
#      | > loss_mel_ce: 2.6868393421173096  (2.886070211728413)
#      | > loss: 0.03237093612551689  (0.03475060352745155)
#      | > current_lr: 5e-06
#      | > step_time: 3.9101  (2.930687715609869)
#      | > loader_time: 0.0055  (0.0057540833950042725)
#
#
#    --> TIME: 2024-05-24 05:27:52 -- STEP: 74/128 -- GLOBAL_STEP: 2250
#      | > loss_text_ce: 0.035568345338106155  (0.03171945647714105)
#      | > loss_mel_ce: 2.7636301517486572  (2.8582015939660983)
#      | > loss: 0.03332379087805748  (0.03440382246028732)
#      | > current_lr: 5e-06
#      | > step_time: 3.4616  (3.2557067935531205)
#      | > loader_time: 0.0058  (0.006071071367006044)
#
#
#    --> TIME: 2024-05-24 05:31:58 -- STEP: 124/128 -- GLOBAL_STEP: 2300
#      | > loss_text_ce: 0.03294806182384491  (0.032085830210557865)
#      | > loss_mel_ce: 2.848478317260742  (2.8846647008772823)
#      | > loss: 0.03430269658565521  (0.03472322117417089)
#      | > current_lr: 5e-06
#      | > step_time: 4.4191  (3.2934720689250576)
#      | > loader_time: 0.0055  (0.0059318215616287725)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.01616811752319336 (-0.002671957015991211)
#      | > avg_loss_text_ce: 0.03151683509349823 (-0.0001582130789756775)
#      | > avg_loss_mel_ce: 2.751538038253784 (-0.012954473495483398)
#      | > avg_loss: 2.783054828643799 (-0.013112783432006836)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_2304.pth
#
#  > EPOCH: 19/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 05:32:21)
#
#    --> TIME: 2024-05-24 05:35:45 -- STEP: 46/128 -- GLOBAL_STEP: 2350
#      | > loss_text_ce: 0.03402104601264  (0.032305798533817986)
#      | > loss_mel_ce: 2.9277408123016357  (2.8387015332346377)
#      | > loss: 0.03525907173752785  (0.034178659441354495)
#      | > current_lr: 5e-06
#      | > step_time: 3.6496  (2.898562716401142)
#      | > loader_time: 0.0063  (0.006894225659577743)
#
#
#    --> TIME: 2024-05-24 05:39:27 -- STEP: 96/128 -- GLOBAL_STEP: 2400
#      | > loss_text_ce: 0.03233819827437401  (0.03199046751251445)
#      | > loss_mel_ce: 2.8709278106689453  (2.8556224629282947)
#      | > loss: 0.034562692046165466  (0.034376345147999636)
#      | > current_lr: 5e-06
#      | > step_time: 2.581  (2.907366988559565)
#      | > loader_time: 0.0059  (0.006486016015211742)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.01731085777282715 (+0.001142740249633789)
#      | > avg_loss_text_ce: 0.03134571388363838 (-0.00017112120985984802)
#      | > avg_loss_mel_ce: 2.7388157844543457 (-0.012722253799438477)
#      | > avg_loss: 2.7701613903045654 (-0.012893438339233398)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_2432.pth
#
#  > EPOCH: 20/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 05:41:57)
#
#    --> TIME: 2024-05-24 05:43:21 -- STEP: 18/128 -- GLOBAL_STEP: 2450
#      | > loss_text_ce: 0.030455423519015312  (0.03265951760113239)
#      | > loss_mel_ce: 2.8430397510528564  (2.86104408899943)
#      | > loss: 0.0342082753777504  (0.03444885307302078)
#      | > current_lr: 5e-06
#      | > step_time: 3.5501  (3.0850666893853083)
#      | > loader_time: 0.0061  (0.006385299894544814)
#
#
#    --> TIME: 2024-05-24 05:47:25 -- STEP: 68/128 -- GLOBAL_STEP: 2500
#      | > loss_text_ce: 0.03135468810796738  (0.032041530809639146)
#      | > loss_mel_ce: 2.9180006980895996  (2.82584310279173)
#      | > loss: 0.03511137515306473  (0.03402243688812151)
#      | > current_lr: 5e-06
#      | > step_time: 3.9277  (3.250315017559949)
#      | > loader_time: 0.006  (0.006159764878890093)
#
#
#    --> TIME: 2024-05-24 05:50:58 -- STEP: 118/128 -- GLOBAL_STEP: 2550
#      | > loss_text_ce: 0.028080366551876068  (0.031580018416299656)
#      | > loss_mel_ce: 2.828835964202881  (2.8555408069642922)
#      | > loss: 0.034010909497737885  (0.03437048675081994)
#      | > current_lr: 5e-06
#      | > step_time: 4.9677  (3.1354778277671946)
#      | > loader_time: 0.0059  (0.006055458117339571)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.018987655639648438 (+0.001676797866821289)
#      | > avg_loss_text_ce: 0.031177343800663948 (-0.0001683700829744339)
#      | > avg_loss_mel_ce: 2.726797580718994 (-0.012018203735351562)
#      | > avg_loss: 2.757974863052368 (-0.012186527252197266)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_2560.pth
#
#  > EPOCH: 21/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 05:51:49)
#
#    --> TIME: 2024-05-24 05:55:22 -- STEP: 40/128 -- GLOBAL_STEP: 2600
#      | > loss_text_ce: 0.029579345136880875  (0.03134268950670958)
#      | > loss_mel_ce: 3.2401182651519775  (2.8345301449298863)
#      | > loss: 0.03892497345805168  (0.03411753410473464)
#      | > current_lr: 5e-06
#      | > step_time: 4.2859  (3.764144790172577)
#      | > loader_time: 0.0062  (0.006227242946624756)
#
#
#    --> TIME: 2024-05-24 05:59:18 -- STEP: 90/128 -- GLOBAL_STEP: 2650
#      | > loss_text_ce: 0.04182136058807373  (0.03115795113974148)
#      | > loss_mel_ce: 3.5247325897216797  (2.8519347031911213)
#      | > loss: 0.04245897755026817  (0.034322532307770486)
#      | > current_lr: 5e-06
#      | > step_time: 2.6975  (3.4899237261878118)
#      | > loader_time: 0.006  (0.006171748373243544)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.016543865203857422 (-0.0024437904357910156)
#      | > avg_loss_text_ce: 0.031009290367364883 (-0.00016805343329906464)
#      | > avg_loss_mel_ce: 2.7178921699523926 (-0.008905410766601562)
#      | > avg_loss: 2.7489013671875 (-0.009073495864868164)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_2688.pth
#
#  > EPOCH: 22/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 06:02:09)
#
#    --> TIME: 2024-05-24 06:02:58 -- STEP: 12/128 -- GLOBAL_STEP: 2700
#      | > loss_text_ce: 0.030289294198155403  (0.032277575538804136)
#      | > loss_mel_ce: 3.0269041061401367  (2.8678680260976157)
#      | > loss: 0.03639516234397888  (0.03452554407219092)
#      | > current_lr: 5e-06
#      | > step_time: 2.2663  (2.4040065010388694)
#      | > loader_time: 0.0058  (0.006196200847625732)
#
#
#    --> TIME: 2024-05-24 06:06:23 -- STEP: 62/128 -- GLOBAL_STEP: 2750
#      | > loss_text_ce: 0.02988285757601261  (0.031487725284551404)
#      | > loss_mel_ce: 2.864068031311035  (2.822412460081039)
#      | > loss: 0.03445179760456085  (0.033975003016812194)
#      | > current_lr: 5e-06
#      | > step_time: 1.8123  (2.5806849695021112)
#      | > loader_time: 0.0059  (0.00643451367655108)
#
#
#    --> TIME: 2024-05-24 06:09:58 -- STEP: 112/128 -- GLOBAL_STEP: 2800
#      | > loss_text_ce: 0.04020210728049278  (0.03142477749913396)
#      | > loss_mel_ce: 2.5842275619506836  (2.8393551451819286)
#      | > loss: 0.031243210658431053  (0.03417595228113768)
#      | > current_lr: 5e-06
#      | > step_time: 2.0203  (2.66664084153516)
#      | > loader_time: 0.0064  (0.006555865917887006)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.030242443084716797 (+0.013698577880859375)
#      | > avg_loss_text_ce: 0.030848264694213867 (-0.00016102567315101624)
#      | > avg_loss_mel_ce: 2.7123937606811523 (-0.005498409271240234)
#      | > avg_loss: 2.743242025375366 (-0.005659341812133789)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_2816.pth
#
#  > EPOCH: 23/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 06:11:16)
#
#    --> TIME: 2024-05-24 06:14:11 -- STEP: 34/128 -- GLOBAL_STEP: 2850
#      | > loss_text_ce: 0.02690383605659008  (0.030816096976837692)
#      | > loss_mel_ce: 2.8342835903167725  (2.809235411531785)
#      | > loss: 0.03406175598502159  (0.03381013788063736)
#      | > current_lr: 5e-06
#      | > step_time: 4.5015  (3.8497276446398567)
#      | > loader_time: 0.0062  (0.006643091931062586)
#
#
#    --> TIME: 2024-05-24 06:17:45 -- STEP: 84/128 -- GLOBAL_STEP: 2900
#      | > loss_text_ce: 0.02569746971130371  (0.030922448240397943)
#      | > loss_mel_ce: 2.4902398586273193  (2.799182480289823)
#      | > loss: 0.029951635748147964  (0.03369172600408394)
#      | > current_lr: 5e-06
#      | > step_time: 1.3867  (3.5014016202517917)
#      | > loader_time: 0.0064  (0.0065503886767796105)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.016010761260986328 (-0.014231681823730469)
#      | > avg_loss_text_ce: 0.030685847625136375 (-0.00016241706907749176)
#      | > avg_loss_mel_ce: 2.708608627319336 (-0.0037851333618164062)
#      | > avg_loss: 2.7392945289611816 (-0.00394749641418457)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_2944.pth
#
#  > EPOCH: 24/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 06:20:51)
#
#    --> TIME: 2024-05-24 06:21:15 -- STEP: 6/128 -- GLOBAL_STEP: 2950
#      | > loss_text_ce: 0.033808525651693344  (0.030864300827185314)
#      | > loss_mel_ce: 2.8137173652648926  (2.870280067125956)
#      | > loss: 0.03389911726117134  (0.034537433025737606)
#      | > current_lr: 5e-06
#      | > step_time: 2.8552  (2.717308243115743)
#      | > loader_time: 0.0061  (0.006118297576904297)
#
#
#    --> TIME: 2024-05-24 06:25:19 -- STEP: 56/128 -- GLOBAL_STEP: 3000
#      | > loss_text_ce: 0.03302524611353874  (0.030438481364399195)
#      | > loss_mel_ce: 2.9684340953826904  (2.794177864279066)
#      | > loss: 0.03573165833950043  (0.033626385764884095)
#      | > current_lr: 5e-06
#      | > step_time: 3.7944  (3.3919242535318648)
#      | > loader_time: 0.0059  (0.006528952292033604)
#
#
#    --> TIME: 2024-05-24 06:29:17 -- STEP: 106/128 -- GLOBAL_STEP: 3050
#      | > loss_text_ce: 0.031063517555594444  (0.030628663030857185)
#      | > loss_mel_ce: 2.7069311141967773  (2.813230903643482)
#      | > loss: 0.03259517624974251  (0.03385547181275093)
#      | > current_lr: 5e-06
#      | > step_time: 3.7631  (3.265569158320157)
#      | > loader_time: 0.0082  (0.00656535490503851)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.018720626831054688 (+0.0027098655700683594)
#      | > avg_loss_text_ce: 0.03052268736064434 (-0.0001631602644920349)
#      | > avg_loss_mel_ce: 2.7027156352996826 (-0.00589299201965332)
#      | > avg_loss: 2.7332382202148438 (-0.006056308746337891)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_3072.pth
#
#  > EPOCH: 25/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 06:31:06)
#
#    --> TIME: 2024-05-24 06:33:14 -- STEP: 28/128 -- GLOBAL_STEP: 3100
#      | > loss_text_ce: 0.029828637838363647  (0.031445100903511054)
#      | > loss_mel_ce: 2.9487388134002686  (2.858101419040135)
#      | > loss: 0.035459134727716446  (0.03439936401056391)
#      | > current_lr: 5e-06
#      | > step_time: 2.5929  (3.1486104811940874)
#      | > loader_time: 0.0063  (0.006298661231994629)
#
#
#    --> TIME: 2024-05-24 06:37:38 -- STEP: 78/128 -- GLOBAL_STEP: 3150
#      | > loss_text_ce: 0.03283422440290451  (0.03130387464681497)
#      | > loss_mel_ce: 2.8700311183929443  (2.8436814516018596)
#      | > loss: 0.034557923674583435  (0.03422601638027491)
#      | > current_lr: 5e-06
#      | > step_time: 3.3217  (3.3944761600249853)
#      | > loader_time: 0.0062  (0.006380759752713717)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.017980575561523438 (-0.00074005126953125)
#      | > avg_loss_text_ce: 0.03036351688206196 (-0.0001591704785823822)
#      | > avg_loss_mel_ce: 2.6949288845062256 (-0.007786750793457031)
#      | > avg_loss: 2.725292444229126 (-0.007945775985717773)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_3200.pth
#
#  > EPOCH: 26/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 06:41:59)
#
#    --> TIME: 2024-05-24 06:42:02 -- STEP: 0/128 -- GLOBAL_STEP: 3200
#      | > loss_text_ce: 0.02803857997059822  (0.02803857997059822)
#      | > loss_mel_ce: 2.7985734939575195  (2.7985734939575195)
#      | > loss: 0.033650144934654236  (0.033650144934654236)
#      | > current_lr: 5e-06
#      | > step_time: 1.7811  (1.7810511589050293)
#      | > loader_time: 0.1445  (0.1445450782775879)
#
#
#    --> TIME: 2024-05-24 06:45:28 -- STEP: 50/128 -- GLOBAL_STEP: 3250
#      | > loss_text_ce: 0.028271030634641647  (0.031223493814468387)
#      | > loss_mel_ce: 2.684710741043091  (2.781445302963257)
#      | > loss: 0.03229740262031555  (0.03348415303975344)
#      | > current_lr: 5e-06
#      | > step_time: 1.1424  (2.6905718994140635)
#      | > loader_time: 0.0064  (0.006534128189086914)
#
#
#    --> TIME: 2024-05-24 06:49:07 -- STEP: 100/128 -- GLOBAL_STEP: 3300
#      | > loss_text_ce: 0.03420398756861687  (0.031438874509185546)
#      | > loss_mel_ce: 3.0663039684295654  (2.8031047582626343)
#      | > loss: 0.03691080957651138  (0.03374456780031324)
#      | > current_lr: 5e-06
#      | > step_time: 2.3234  (2.80044058084488)
#      | > loader_time: 0.006  (0.006514451503753662)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.019379377365112305 (+0.0013988018035888672)
#      | > avg_loss_text_ce: 0.030211204662919044 (-0.00015231221914291382)
#      | > avg_loss_mel_ce: 2.686187267303467 (-0.008741617202758789)
#      | > avg_loss: 2.7163984775543213 (-0.008893966674804688)
#
#  > BEST MODEL : /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0/best_model_3328.pth
#
#  > EPOCH: 27/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 06:50:40)
#
#    --> TIME: 2024-05-24 06:52:16 -- STEP: 22/128 -- GLOBAL_STEP: 3350
#      | > loss_text_ce: 0.029521306976675987  (0.03229445896365426)
#      | > loss_mel_ce: 2.5926401615142822  (2.7622674161737617)
#      | > loss: 0.031216207891702652  (0.033268594860353246)
#      | > current_lr: 5e-06
#      | > step_time: 3.553  (2.5758409066633745)
#      | > loader_time: 0.0065  (0.007073369893160733)
#
#
#    --> TIME: 2024-05-24 06:56:13 -- STEP: 72/128 -- GLOBAL_STEP: 3400
#      | > loss_text_ce: 0.03123057447373867  (0.03166523930202756)
#      | > loss_mel_ce: 2.9607465267181396  (2.805559664964676)
#      | > loss: 0.03561877831816673  (0.03377648781881565)
#      | > current_lr: 5e-06
#      | > step_time: 3.7987  (2.891635394758649)
#      | > loader_time: 0.0066  (0.006967852512995402)
#
#
#    --> TIME: 2024-05-24 07:00:18 -- STEP: 122/128 -- GLOBAL_STEP: 3450
#      | > loss_text_ce: 0.028667651116847992  (0.03104271732087508)
#      | > loss_mel_ce: 2.6646342277526855  (2.806307607009763)
#      | > loss: 0.03206311911344528  (0.033777980882002664)
#      | > current_lr: 5e-06
#      | > step_time: 2.2655  (2.960569053399759)
#      | > loader_time: 0.006  (0.00669194049522525)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.019916534423828125 (+0.0005371570587158203)
# ...
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.023126602172851562 (-0.0011510848999023438)
#      | > avg_loss_text_ce: 0.027018992230296135 (-7.1320682764053345e-06)
#      | > avg_loss_mel_ce: 2.57230806350708 (+0.008126020431518555)
#      | > avg_loss: 2.5993270874023438 (+0.008118867874145508)
#
#
#  > EPOCH: 90/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 17:45:39)
#
#    --> TIME: 2024-05-24 17:46:11 -- STEP: 8/128 -- GLOBAL_STEP: 11400
#      | > loss_text_ce: 0.03366599231958389  (0.027392274932935834)
#      | > loss_mel_ce: 2.0638809204101562  (2.251569539308548)
#      | > loss: 0.024970795959234238  (0.027130498318001628)
#      | > current_lr: 5e-06
#      | > step_time: 2.2064  (2.351621448993683)
#      | > loader_time: 0.0109  (0.00873720645904541)
#
#
#    --> TIME: 2024-05-24 17:51:16 -- STEP: 58/128 -- GLOBAL_STEP: 11450
#      | > loss_text_ce: 0.028758332133293152  (0.027593918273161197)
#      | > loss_mel_ce: 2.5013818740844727  (2.2482366582442976)
#      | > loss: 0.030120717361569405  (0.027093221690377284)
#      | > current_lr: 5e-06
#      | > step_time: 3.9419  (3.892990601473841)
#      | > loader_time: 0.0086  (0.008663292588858772)
#
#
#    --> TIME: 2024-05-24 17:55:35 -- STEP: 108/128 -- GLOBAL_STEP: 11500
#      | > loss_text_ce: 0.03240694850683212  (0.026979005291920016)
#      | > loss_mel_ce: 2.548304557800293  (2.238276905483669)
#      | > loss: 0.030722757801413536  (0.026967332836378505)
#      | > current_lr: 5e-06
#      | > step_time: 4.3236  (3.7202157378196716)
#      | > loader_time: 0.0081  (0.008721040354834666)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.021320819854736328 (-0.0018057823181152344)
#      | > avg_loss_text_ce: 0.027012672275304794 (-6.319954991340637e-06)
#      | > avg_loss_mel_ce: 2.5701324939727783 (-0.002175569534301758)
#      | > avg_loss: 2.5971450805664062 (-0.0021820068359375)
#
#
#  > EPOCH: 91/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 17:57:19)
#
#    --> TIME: 2024-05-24 17:59:40 -- STEP: 30/128 -- GLOBAL_STEP: 11550
#      | > loss_text_ce: 0.02520413137972355  (0.025996116548776628)
#      | > loss_mel_ce: 2.1345055103302  (2.232860799630482)
#      | > loss: 0.025710830464959145  (0.02689115423709154)
#      | > current_lr: 5e-06
#      | > step_time: 3.3163  (3.4837406237920123)
#      | > loader_time: 0.0089  (0.008804321289062498)
#
#
#    --> TIME: 2024-05-24 18:03:49 -- STEP: 80/128 -- GLOBAL_STEP: 11600
#      | > loss_text_ce: 0.021839696913957596  (0.026620960514992475)
#      | > loss_mel_ce: 2.134913682937622  (2.2688881695270533)
#      | > loss: 0.025675635784864426  (0.02732749010901898)
#      | > current_lr: 5e-06
#      | > step_time: 2.1312  (3.646614617109299)
#      | > loader_time: 0.0095  (0.009008380770683288)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02138042449951172 (+5.9604644775390625e-05)
#      | > avg_loss_text_ce: 0.027006275951862335 (-6.3963234424591064e-06)
#      | > avg_loss_mel_ce: 2.5673274993896484 (-0.002804994583129883)
#      | > avg_loss: 2.5943338871002197 (-0.0028111934661865234)
#
#
#  > EPOCH: 92/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 18:08:27)
#
#    --> TIME: 2024-05-24 18:08:39 -- STEP: 2/128 -- GLOBAL_STEP: 11650
#      | > loss_text_ce: 0.03240416944026947  (0.029291328974068165)
#      | > loss_mel_ce: 2.4002671241760254  (2.3065298795700073)
#      | > loss: 0.028960373252630234  (0.027807396836578846)
#      | > current_lr: 5e-06
#      | > step_time: 4.3592  (3.085471987724304)
#      | > loader_time: 0.0089  (0.008469343185424805)
#
#
#    --> TIME: 2024-05-24 18:12:24 -- STEP: 52/128 -- GLOBAL_STEP: 11700
#      | > loss_text_ce: 0.026508018374443054  (0.026743574999272823)
#      | > loss_mel_ce: 2.0855729579925537  (2.285440435776342)
#      | > loss: 0.02514382265508175  (0.027526000908647593)
#      | > current_lr: 5e-06
#      | > step_time: 1.4187  (3.10627432511403)
#      | > loader_time: 0.0085  (0.008921912083258996)
#
#
#    --> TIME: 2024-05-24 18:16:03 -- STEP: 102/128 -- GLOBAL_STEP: 11750
#      | > loss_text_ce: 0.02582724764943123  (0.02675462050326899)
#      | > loss_mel_ce: 2.1073036193847656  (2.2694707840096697)
#      | > loss: 0.025394415482878685  (0.027336017319969104)
#      | > current_lr: 5e-06
#      | > step_time: 3.7378  (3.0169681708017984)
#      | > loader_time: 0.0082  (0.008761536841299017)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.03203439712524414 (+0.010653972625732422)
#      | > avg_loss_text_ce: 0.027002088725566864 (-4.187226295471191e-06)
#      | > avg_loss_mel_ce: 2.5648531913757324 (-0.0024743080139160156)
#      | > avg_loss: 2.59185528755188 (-0.0024785995483398438)
#
#
#  > EPOCH: 93/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 18:17:57)
#
#    --> TIME: 2024-05-24 18:20:13 -- STEP: 24/128 -- GLOBAL_STEP: 11800
#      | > loss_text_ce: 0.023852240294218063  (0.026965552164862554)
#      | > loss_mel_ce: 2.3036370277404785  (2.238648772239685)
#      | > loss: 0.027708208188414574  (0.02697159970800082)
#      | > current_lr: 5e-06
#      | > step_time: 1.5837  (4.090501407782237)
#      | > loader_time: 0.0084  (0.009012788534164429)
#
#
#    --> TIME: 2024-05-24 18:24:23 -- STEP: 74/128 -- GLOBAL_STEP: 11850
#      | > loss_text_ce: 0.025835849344730377  (0.027058566970801032)
#      | > loss_mel_ce: 1.993882656097412  (2.2222445977700716)
#      | > loss: 0.02404426783323288  (0.026777419160950826)
#      | > current_lr: 5e-06
#      | > step_time: 4.1652  (3.734371233630825)
#      | > loader_time: 0.0087  (0.009113975473352381)
#
#
#    --> TIME: 2024-05-24 18:28:43 -- STEP: 124/128 -- GLOBAL_STEP: 11900
#      | > loss_text_ce: 0.02414151467382908  (0.0268714394450428)
#      | > loss_mel_ce: 2.1955597400665283  (2.2091362870508617)
#      | > loss: 0.026425015181303024  (0.026619140133862535)
#      | > current_lr: 5e-06
#      | > step_time: 3.7888  (3.716011743391714)
#      | > loader_time: 0.0075  (0.00877561107758553)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.01827836036682129 (-0.013756036758422852)
#      | > avg_loss_text_ce: 0.02700435183942318 (+2.263113856315613e-06)
#      | > avg_loss_mel_ce: 2.5664703845977783 (+0.0016171932220458984)
#      | > avg_loss: 2.5934746265411377 (+0.0016193389892578125)
#
#
#  > EPOCH: 94/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 18:28:58)
#
#    --> TIME: 2024-05-24 18:33:09 -- STEP: 46/128 -- GLOBAL_STEP: 11950
#      | > loss_text_ce: 0.03355593979358673  (0.026971490284347015)
#      | > loss_mel_ce: 2.2249467372894287  (2.256815487923829)
#      | > loss: 0.026886938139796257  (0.027187940502620262)
#      | > current_lr: 5e-06
#      | > step_time: 4.008  (4.07001525422801)
#      | > loader_time: 0.0099  (0.00936518026434857)
#
#
#    --> TIME: 2024-05-24 18:38:18 -- STEP: 96/128 -- GLOBAL_STEP: 12000
#      | > loss_text_ce: 0.03048544190824032  (0.02677580623033767)
#      | > loss_mel_ce: 2.046433925628662  (2.24206251030167)
#      | > loss: 0.024725230410695076  (0.02700998036501308)
#      | > current_lr: 5e-06
#      | > step_time: 3.0777  (4.294742075105507)
#      | > loader_time: 0.0087  (0.00913338114817937)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02479696273803711 (+0.00651860237121582)
#      | > avg_loss_text_ce: 0.02700750343501568 (+3.1515955924987793e-06)
#      | > avg_loss_mel_ce: 2.5674633979797363 (+0.0009930133819580078)
#      | > avg_loss: 2.594470977783203 (+0.0009963512420654297)
#
#
#  > EPOCH: 95/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 18:41:50)
#
#    --> TIME: 2024-05-24 18:43:23 -- STEP: 18/128 -- GLOBAL_STEP: 12050
#      | > loss_text_ce: 0.029507579281926155  (0.027433296665549278)
#      | > loss_mel_ce: 2.357513189315796  (2.2201551530096264)
#      | > loss: 0.028416914865374565  (0.02675700591256221)
#      | > current_lr: 5e-06
#      | > step_time: 2.4854  (3.6913840770721436)
#      | > loader_time: 0.0085  (0.009055217107137045)
#
#
#    --> TIME: 2024-05-24 18:55:36 -- STEP: 68/128 -- GLOBAL_STEP: 12100
#      | > loss_text_ce: 0.027590062469244003  (0.026259442243505928)
#      | > loss_mel_ce: 2.280539035797119  (2.2078135311603546)
#      | > loss: 0.027477728202939034  (0.026596107246244654)
#      | > current_lr: 5e-06
#      | > step_time: 4.0237  (8.794629089972553)
#      | > loader_time: 0.0092  (0.00934310169780956)
#
#
#    --> TIME: 2024-05-24 19:00:22 -- STEP: 118/128 -- GLOBAL_STEP: 12150
#      | > loss_text_ce: 0.023513132706284523  (0.026888299938607012)
#      | > loss_mel_ce: 2.071460723876953  (2.2266662262253853)
#      | > loss: 0.024940164759755135  (0.026828030455794374)
#      | > current_lr: 5e-06
#      | > step_time: 3.7196  (6.660560991804481)
#      | > loader_time: 0.0076  (0.009328480494224424)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.020378589630126953 (-0.004418373107910156)
#      | > avg_loss_text_ce: 0.027008840814232826 (+1.3373792171478271e-06)
#      | > avg_loss_mel_ce: 2.5676610469818115 (+0.0001976490020751953)
#      | > avg_loss: 2.594669818878174 (+0.00019884109497070312)
#
#
#  > EPOCH: 96/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 19:01:14)
#
#    --> TIME: 2024-05-24 19:05:11 -- STEP: 40/128 -- GLOBAL_STEP: 12200
#      | > loss_text_ce: 0.02928091399371624  (0.02659955401904881)
#      | > loss_mel_ce: 2.5800836086273193  (2.2005463242530823)
#      | > loss: 0.0310638640075922  (0.026513642026111485)
#      | > current_lr: 5e-06
#      | > step_time: 3.3899  (3.758779639005661)
#      | > loader_time: 0.0082  (0.008644354343414307)
#
#
#    --> TIME: 2024-05-24 19:09:40 -- STEP: 90/128 -- GLOBAL_STEP: 12250
#      | > loss_text_ce: 0.02162664383649826  (0.026979754058023293)
#      | > loss_mel_ce: 2.3898653984069824  (2.223232781887055)
#      | > loss: 0.028708240017294884  (0.026788245079418023)
#      | > current_lr: 5e-06
#      | > step_time: 3.2806  (3.5309990061653984)
#      | > loader_time: 0.0077  (0.008860325813293454)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.020209312438964844 (-0.00016927719116210938)
#      | > avg_loss_text_ce: 0.02700917422771454 (+3.334134817123413e-07)
#      | > avg_loss_mel_ce: 2.573322296142578 (+0.0056612491607666016)
#      | > avg_loss: 2.6003315448760986 (+0.005661725997924805)
#
#
#  > EPOCH: 97/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 19:12:40)
#
#    --> TIME: 2024-05-24 19:13:30 -- STEP: 12/128 -- GLOBAL_STEP: 12300
#      | > loss_text_ce: 0.02616244927048683  (0.026138766823957365)
#      | > loss_mel_ce: 2.2152931690216064  (2.166175792614619)
#      | > loss: 0.026683995500206947  (0.026098983207096655)
#      | > current_lr: 5e-06
#      | > step_time: 2.5768  (2.8357961177825928)
#      | > loader_time: 0.0078  (0.00966954231262207)
#
#
#    --> TIME: 2024-05-24 19:17:22 -- STEP: 62/128 -- GLOBAL_STEP: 12350
#      | > loss_text_ce: 0.02424732595682144  (0.02663825482370392)
#      | > loss_mel_ce: 1.905935525894165  (2.215516159611364)
#      | > loss: 0.022978367283940315  (0.026692314974723325)
#      | > current_lr: 5e-06
#      | > step_time: 2.4894  (2.8266893009985656)
#      | > loader_time: 0.0081  (0.008982354594815159)
#
#
#    --> TIME: 2024-05-24 19:21:18 -- STEP: 112/128 -- GLOBAL_STEP: 12400
#      | > loss_text_ce: 0.028345869854092598  (0.026640291791409254)
#      | > loss_mel_ce: 2.1101109981536865  (2.225107120616095)
#      | > loss: 0.025457819923758507  (0.026806517271324992)
#      | > current_lr: 5e-06
#      | > step_time: 5.2518  (2.875244943158968)
#      | > loader_time: 0.0081  (0.008720080767359048)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.035234928131103516 (+0.015025615692138672)
#      | > avg_loss_text_ce: 0.02701072208583355 (+1.5478581190109253e-06)
#      | > avg_loss_mel_ce: 2.5820000171661377 (+0.00867772102355957)
#      | > avg_loss: 2.609010696411133 (+0.00867915153503418)
#
#
#  > EPOCH: 98/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 19:22:19)
#
#    --> TIME: 2024-05-24 19:25:37 -- STEP: 34/128 -- GLOBAL_STEP: 12450
#      | > loss_text_ce: 0.03151644393801689  (0.02675358479952111)
#      | > loss_mel_ce: 1.9692729711532593  (2.2075251200619874)
#      | > loss: 0.02381892129778862  (0.02659855635069749)
#      | > current_lr: 5e-06
#      | > step_time: 4.4049  (3.8569939136505127)
#      | > loader_time: 0.0077  (0.008321327321669635)
#
#
#    --> TIME: 2024-05-24 19:31:09 -- STEP: 84/128 -- GLOBAL_STEP: 12500
#      | > loss_text_ce: 0.032214026898145676  (0.02666044244099231)
#      | > loss_mel_ce: 2.3241002559661865  (2.194606575227918)
#      | > loss: 0.028051359578967094  (0.026443655425239177)
#      | > current_lr: 5e-06
#      | > step_time: 2.9452  (4.128668708460673)
#      | > loader_time: 0.0079  (0.00836650530497233)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.021448373794555664 (-0.013786554336547852)
#      | > avg_loss_text_ce: 0.027014881372451782 (+4.159286618232727e-06)
#      | > avg_loss_mel_ce: 2.5856544971466064 (+0.00365447998046875)
#      | > avg_loss: 2.6126694679260254 (+0.003658771514892578)
#
#
#  > EPOCH: 99/100
#  --> /home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_02+37AM-64158d0
#
#  > TRAINING (2024-05-24 19:36:02)
#
#    --> TIME: 2024-05-24 19:36:27 -- STEP: 6/128 -- GLOBAL_STEP: 12550
#      | > loss_text_ce: 0.023310722783207893  (0.027755912393331528)
#      | > loss_mel_ce: 2.3120763301849365  (2.175436496734619)
#      | > loss: 0.027802227064967155  (0.02622848190367222)
#      | > current_lr: 5e-06
#      | > step_time: 2.9789  (2.8035531441370645)
#      | > loader_time: 0.0073  (0.008437911669413248)
#
#
#    --> TIME: 2024-05-24 19:41:07 -- STEP: 56/128 -- GLOBAL_STEP: 12600
#      | > loss_text_ce: 0.03510754927992821  (0.02655182931838291)
#      | > loss_mel_ce: 1.9873682260513306  (2.189394112144198)
#      | > loss: 0.024077093228697777  (0.026380309402676567)
#      | > current_lr: 5e-06
#      | > step_time: 2.6084  (3.7183177130562917)
#      | > loader_time: 0.0084  (0.00866967865398952)
#
#
#    --> TIME: 2024-05-24 19:45:55 -- STEP: 106/128 -- GLOBAL_STEP: 12650
#      | > loss_text_ce: 0.0334402397274971  (0.027212390588280164)
#      | > loss_mel_ce: 1.9927332401275635  (2.192982355378709)
#      | > loss: 0.0241211149841547  (0.02643089049126742)
#      | > current_lr: 5e-06
#      | > step_time: 2.1001  (3.7969628797387176)
#      | > loader_time: 0.0098  (0.008564555420065827)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.021205425262451172 (-0.0002429485321044922)
#      | > avg_loss_text_ce: 0.027019551023840904 (+4.669651389122009e-06)
#      | > avg_loss_mel_ce: 2.58459210395813 (-0.0010623931884765625)
#      | > avg_loss: 2.6116116046905518 (-0.0010578632354736328)

# %%
# !tensorboard --logdir=/home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-24-2024_09+00PM-64158d0
# Out:
# TensorFlow installation not found - running with reduced feature set.
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.16.2 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %%
# !tensorboard --logdir=/home/pengejeen/paymon_v0.0.1/paimon_llama2-enhanced/tts_paimon/TTS/recipes/ljspeech/xtts_v2/run/training/paimon_ko-May-23-2024_11+57PM-64158d0
# Out:
# TensorFlow installation not found - running with reduced feature set.
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.16.2 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %%
 # !tts --model_name tts_models/multilingual/multi-dataset/xtts_v2 \
     --text "시발" \
     --speaker_idx "Ana Florence" \
     --language_idx ko \
     --use_cuda true
# Out:
#  > tts_models/multilingual/multi-dataset/xtts_v2 is already downloaded.
#  > Using model: xtts
#  > Text: 시발
#  > Text splitted to sentences.
# ['시발']
#  > Processing time: 0.9812474250793457
#  > Real-time factor: 0.5280287417756632
#  > Saving output to tts_output.wav
